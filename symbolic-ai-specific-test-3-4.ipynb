# %% [markdown]
# ### Common Test 1.2

# %%
import re
import random
from pathlib import Path
import json

# Regex pattern to tokenize expressions:
# The pattern captures:
#   - Words (letters and underscores)
#   - Numbers (including those with decimal points)
#   - Mathematical operators and punctuation (like +, -, *, /, ^, parentheses, braces, etc.)
token_pattern = re.compile(r'([A-Za-z_]+|\d+\.\d+|\d+|[+\-*/^(){}\[\]:,])')

def normalize_indices(seq):
    """
    Normalizes indices of the form _<number> in a given sequence.
    Each unique index is replaced with a normalized index (_1, _2, ...)
    in order of appearance.
    """
    # Pattern to find indices like _123456
    index_pattern = re.compile(r'_(\d+)')
    mapping = {}
    normalized_seq = seq

    # Find all indices in order of appearance
    for match in index_pattern.finditer(seq):
        full_token = match.group(0)  # e.g., '_239'
        if full_token not in mapping:
            # Assign the next available normalized index (starting at 1)
            mapping[full_token] = f"_{len(mapping) + 1}"
    # Replace the indices using the mapping.
    for original, normalized in mapping.items():
        normalized_seq = normalized_seq.replace(original, normalized)
    return normalized_seq

def tokenize(text):
    """
    Tokenizes the given text using the token_pattern.
    Returns a list of tokens.
    """
    return token_pattern.findall(text)

def process_file(file_content):
    """
    Processes the content of a file.
    Assumes each row is of the format:
      event type : Feynman diagram : amplitude : squared amplitude
    Returns a list of dictionaries with tokenized amplitude and squared amplitude,
    along with the raw event type and Feynman diagram for reference.
    """
    processed_rows = []
    for line in file_content.strip().splitlines():
        # Skip empty lines
        if not line.strip():
            continue
        # Split the line into four parts by " : "
        parts = [p.strip() for p in line.split(" : ")]
        if len(parts) != 4:
            print(f"Skipping malformed line: {line}")
            continue
        event_type, feynman_diag, amplitude, squared_amplitude = parts

        # Normalize indices for amplitude and squared amplitude
        amplitude_norm = normalize_indices(amplitude)
        squared_amplitude_norm = normalize_indices(squared_amplitude)

        # Tokenize amplitude and squared amplitude
        amplitude_tokens = tokenize(amplitude_norm)
        squared_amplitude_tokens = tokenize(squared_amplitude_norm)

        processed_rows.append({
            "event_type": event_type,
            "feynman_diag": feynman_diag,
            "amplitude_tokens": amplitude_tokens,
            "squared_amplitude_tokens": squared_amplitude_tokens
        })
    return processed_rows

def load_and_process_folder(folder_path):
    """
    Reads all text files in the provided folder and processes them.
    Returns the aggregated list of processed rows.
    """
    all_data = []
    folder = Path(folder_path)
    # Glob for .txt files in the folder
    text_files = list(folder.glob("*.txt"))
    for file_path in text_files:
        with file_path.open("r", encoding="utf-8") as f:
            content = f.read()
            file_data = process_file(content)
            all_data.extend(file_data)
    return all_data

def split_dataset(data, train_ratio=0.8, val_ratio=0.1, test_ratio=0.1):
    """
    Shuffles and splits the data into train, validation, and test sets.
    """
    random.shuffle(data)
    total = len(data)
    train_end = int(total * train_ratio)
    val_end = train_end + int(total * val_ratio)
    train_set = data[:train_end]
    val_set = data[train_end:val_end]
    test_set = data[val_end:]
    return train_set, val_set, test_set

# Main processing
folder_path = "/kaggle/input/squared-amplitude/SYMBA - Test Data"  # Path to the folder containing extracted text files.
all_processed_data = load_and_process_folder(folder_path)
print(f"Total examples processed: {len(all_processed_data)}")

# Split the dataset
train_set, val_set, test_set = split_dataset(all_processed_data)
print(f"Train set: {len(train_set)} examples")
print(f"Validation set: {len(val_set)} examples")
print(f"Test set: {len(test_set)} examples")

# Optionally, save the splits to disk as JSON for further processing
output_dir = Path("processed_data")
output_dir.mkdir(exist_ok=True)
with open(output_dir / "train.json", "w", encoding="utf-8") as f:
    json.dump(train_set, f, indent=2)
with open(output_dir / "val.json", "w", encoding="utf-8") as f:
    json.dump(val_set, f, indent=2)
with open(output_dir / "test.json", "w", encoding="utf-8") as f:
    json.dump(test_set, f, indent=2)

print("Data processing and splitting completed.")
# Out:
# Total examples processed: 15552
# Train set: 12441 examples
# Validation set: 1555 examples
# Test set: 1556 examples
# Data processing and splitting completed.

# %% [markdown]
# ### Common Task 2 BERT

# %%
import math
import json
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# ---------------------
# 1. Special Tokens & Vocabulary
# ---------------------
SPECIAL_TOKENS = {
    "<pad>": 0,
    "<bos>": 1,
    "<eos>": 2,
    "<mask>": 3
}

def build_vocab(dataset):
    """
    Build vocabulary from a dataset.
    Each example is a dict with keys "amplitude_tokens" and "squared_amplitude_tokens".
    Both lists are iterated over to add tokens to the vocabulary.
    """
    vocab = dict(SPECIAL_TOKENS)
    for example in dataset:
        for token in example["amplitude_tokens"]:
            if token not in vocab:
                vocab[token] = len(vocab)
        for token in example["squared_amplitude_tokens"]:
            if token not in vocab:
                vocab[token] = len(vocab)
    return vocab

# ---------------------
# 2. Dataset and DataLoader
# ---------------------
class LanguageModelDataset(Dataset):
    def __init__(self, data, vocab, max_len=200):
        """
        data: list of dicts; each dict has keys "amplitude_tokens" and "squared_amplitude_tokens".
              Each value is a list of token strings.
        vocab: mapping from token to index.
        max_len: maximum sequence length (sequence is truncated if longer).
        """
        self.data = data
        self.vocab = vocab
        self.max_len = max_len

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        example = self.data[idx]
        # Combine tokens from both columns.
        tokens = ([SPECIAL_TOKENS["<bos>"]] +
                  [self.vocab[token] for token in example["amplitude_tokens"]] +
                  [self.vocab[token] for token in example["squared_amplitude_tokens"]] +
                  [SPECIAL_TOKENS["<eos>"]])
        tokens = tokens[:self.max_len]
        return torch.tensor(tokens, dtype=torch.long)

def collate_fn(batch):
    batch_size = len(batch)
    max_len = max(len(x) for x in batch)
    padded = torch.full((batch_size, max_len), SPECIAL_TOKENS["<pad>"], dtype=torch.long)
    for i, seq in enumerate(batch):
        padded[i, :len(seq)] = seq
    return padded

# ---------------------
# 3. Positional Encoding Module
# ---------------------
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        """
        Registers positional encodings with shape (max_len, 1, d_model) to be added
        to inputs of shape (seq_len, batch, d_model).
        """
        super().__init__()
        self.dropout = nn.Dropout(p=dropout)
        pe = torch.zeros(max_len, d_model)  # (max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)  # (max_len, 1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(1)  # (max_len, 1, d_model)
        self.register_buffer("pe", pe)

    def forward(self, x):
        # x: (seq_len, batch, d_model)
        x = x + self.pe[:x.size(0)]
        return self.dropout(x)

# ---------------------
# 4. Masking Function for MLM
# ---------------------
def mask_tokens(inputs, mask_token_id, vocab_size, mlm_probability=0.15):
    """
    Prepare masked tokens inputs/labels for masked language modeling.
    inputs: Tensor of shape (batch, seq_len)
    Returns: masked_inputs, labels (labels is -100 for tokens that are not masked)
    """
    # Ensure we create new tensors on the same device as inputs.
    labels = inputs.clone()
    probability_matrix = torch.full(labels.shape, mlm_probability, device=inputs.device)
    special_tokens_mask = (inputs == SPECIAL_TOKENS["<bos>"]) | \
                          (inputs == SPECIAL_TOKENS["<eos>"]) | \
                          (inputs == SPECIAL_TOKENS["<pad>"])
    probability_matrix.masked_fill_(special_tokens_mask, value=0.0)
    masked_indices = torch.bernoulli(probability_matrix).bool()
    labels[~masked_indices] = -100  # Only compute loss on masked tokens.

    # 80% of the time, replace masked tokens with <mask>
    indices_replaced = torch.bernoulli(torch.full(labels.shape, 0.8, device=inputs.device)).bool() & masked_indices
    inputs[indices_replaced] = mask_token_id

    # 10% of the time, replace masked tokens with a random token
    indices_random = torch.bernoulli(torch.full(labels.shape, 0.5, device=inputs.device)).bool() & masked_indices & ~indices_replaced
    random_words = torch.randint(low=0, high=vocab_size, size=inputs.shape, device=inputs.device)
    inputs[indices_random] = random_words[indices_random]
    # The rest 10% keep the original token.
    return inputs, labels

# ---------------------
# 5. BERT-Style Model for Masked Language Modeling
# ---------------------
class BertForMaskedLM(nn.Module):
    def __init__(self, vocab_size, d_model=128, nhead=8, num_layers=6, dropout=0.1):
        """
        A BERT-style model for masked language modeling.
        It uses a bidirectional Transformer encoder (without causal masking).
        """
        super().__init__()
        self.d_model = d_model
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.pos_encoder = PositionalEncoding(d_model, dropout)
        encoder_layer = nn.TransformerEncoderLayer(d_model, nhead, dim_feedforward=4*d_model, dropout=dropout)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers)
        self.fc_out = nn.Linear(d_model, vocab_size)

    def forward(self, src, src_padding_mask=None):
        # src: (seq_len, batch)
        emb = self.embedding(src) * math.sqrt(self.d_model)
        emb = self.pos_encoder(emb)
        # Bidirectional encoding: no causal mask is applied.
        out = self.transformer_encoder(emb, src_key_padding_mask=src_padding_mask)
        logits = self.fc_out(out)  # (seq_len, batch, vocab_size)
        return logits

# ---------------------
# 6. Helper Function for Padding Masking
# ---------------------
def generate_padding_mask(batch, pad_idx=SPECIAL_TOKENS["<pad>"]):
    # batch: (batch, seq_len)
    return (batch == pad_idx)

# ---------------------
# 7. Training and Evaluation Functions for MLM
# ---------------------
def train_epoch_bert(model, dataloader, optimizer, criterion, device, mlm_probability=0.15):
    model.train()
    total_loss = 0.0
    for batch in dataloader:
        batch = batch.to(device)  # (batch, seq_len)
        masked_inputs, labels = mask_tokens(batch.clone(), SPECIAL_TOKENS["<mask>"], vocab_size, mlm_probability)
        # Transpose for Transformer: (seq_len, batch)
        masked_inputs = masked_inputs.transpose(0, 1)
        labels = labels.transpose(0, 1)
        padding_mask = generate_padding_mask(batch).to(device)
        optimizer.zero_grad()
        logits = model(masked_inputs, src_padding_mask=padding_mask)
        loss = criterion(logits.view(-1, logits.size(-1)), labels.reshape(-1))
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(dataloader)

def evaluate_bert(model, dataloader, criterion, device, mlm_probability=0.15):
    model.eval()
    total_loss = 0.0
    with torch.no_grad():
        for batch in dataloader:
            batch = batch.to(device)
            masked_inputs, labels = mask_tokens(batch.clone(), SPECIAL_TOKENS["<mask>"], vocab_size, mlm_probability)
            masked_inputs = masked_inputs.transpose(0, 1)
            labels = labels.transpose(0, 1)
            padding_mask = generate_padding_mask(batch).to(device)
            logits = model(masked_inputs, src_padding_mask=padding_mask)
            loss = criterion(logits.view(-1, logits.size(-1)), labels.reshape(-1))
            total_loss += loss.item()
    return total_loss / len(dataloader)

# ---------------------
# 8. Display Predictions for Masked Tokens
# ---------------------
def display_predictions_bert(model, dataloader, vocab, num_examples=5, device=torch.device("cpu")):
    """
    For each example, display the original sequence with masked tokens replaced by the model's prediction.
    """
    rev_vocab = {v: k for k, v in vocab.items()}
    model.eval()
    examples_shown = 0
    with torch.no_grad():
        for batch in dataloader:
            batch = batch.to(device)
            # For display, mask the input using mask_tokens (with mlm_probability=0.15)
            masked_inputs, _ = mask_tokens(batch.clone(), SPECIAL_TOKENS["<mask>"], len(vocab), mlm_probability=0.15)
            for i in range(masked_inputs.size(0)):
                input_seq = masked_inputs[i].unsqueeze(0)  # (1, seq_len)
                input_seq_t = input_seq.transpose(0, 1)      # (seq_len, 1)
                padding_mask = generate_padding_mask(input_seq).to(device)
                logits = model(input_seq_t, src_padding_mask=padding_mask)
                logits = logits.transpose(0, 1)  # (1, seq_len, vocab_size)
                predictions = torch.argmax(logits, dim=-1).squeeze(0).cpu().tolist()

                # For positions that were masked in the input, use the model's prediction; else, show the original token.
                original = batch[i].cpu().tolist()
                display_seq = []
                # We iterate over the original sequence. If the token in the masked input is <mask>,
                # we pop one token from predictions.
                for orig, inp in zip(original, input_seq[0].cpu().tolist()):
                    if inp == SPECIAL_TOKENS["<mask>"]:
                        # If predictions list is empty, use <unk>
                        display_seq.append(rev_vocab.get(predictions.pop(0) if predictions else None, "<unk>"))
                    else:
                        display_seq.append(rev_vocab.get(orig, "<unk>"))
                print("Input (masked replaced by prediction):", " ".join(display_seq))
                print("-" * 50)
                examples_shown += 1
                if examples_shown >= num_examples:
                    return

# ---------------------
# 9. Main Training Loop and Testing
# ---------------------
if __name__ == "__main__":
    # Load data from JSON files.
    # Each file is expected to be a list of examples with keys "amplitude_tokens" and "squared_amplitude_tokens".
    with open("processed_data/train.json") as f:
        train_data = json.load(f)
    with open("processed_data/val.json") as f:
        val_data = json.load(f)
    with open("processed_data/test.json") as f:
        test_data = json.load(f)

    # Build vocabulary from combined data.
    combined_data = train_data + val_data + test_data
    vocab = build_vocab(combined_data)
    vocab_size = len(vocab)
    print(f"Vocabulary size: {vocab_size}")

    # Create dataset by combining tokens from both columns.
    train_dataset = LanguageModelDataset(train_data, vocab, max_len=200)
    val_dataset = LanguageModelDataset(val_data, vocab, max_len=200)
    test_dataset = LanguageModelDataset(test_data, vocab, max_len=200)

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=collate_fn)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, collate_fn=collate_fn)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, collate_fn=collate_fn)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = BertForMaskedLM(vocab_size, d_model=128, nhead=8, num_layers=6, dropout=0.1)
    model = model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    # Use -100 as ignore_index for loss computation.
    criterion = nn.CrossEntropyLoss(ignore_index=-100)

    num_epochs = 500
    for epoch in range(1, num_epochs + 1):
        train_loss = train_epoch_bert(model, train_loader, optimizer, criterion, device, mlm_probability=0.15)
        val_loss = evaluate_bert(model, val_loader, criterion, device, mlm_probability=0.15)
        print(f"Epoch {epoch}: Train Loss = {train_loss:.4f}, Val Loss = {val_loss:.4f}")

    # Display sample predictions (masked token predictions) from the test set.
    print("\nSample Predictions on Test Data:")
    display_predictions_bert(model, test_loader, vocab, num_examples=5, device=device)
# Out:
# Vocabulary size: 32828
# Epoch 1: Train Loss = 3.8072, Val Loss = 3.3031
# Epoch 2: Train Loss = 3.1891, Val Loss = 2.9602
# Epoch 3: Train Loss = 2.9058, Val Loss = 2.6946
# Epoch 4: Train Loss = 2.6199, Val Loss = 2.4222
# Epoch 5: Train Loss = 2.3676, Val Loss = 2.1747
# Epoch 6: Train Loss = 2.1512, Val Loss = 1.9753
# Epoch 7: Train Loss = 1.9693, Val Loss = 1.7926
# Epoch 8: Train Loss = 1.8327, Val Loss = 1.6760
# Epoch 9: Train Loss = 1.7288, Val Loss = 1.6019
# Epoch 10: Train Loss = 1.6275, Val Loss = 1.5048
# Epoch 11: Train Loss = 1.5547, Val Loss = 1.4133
# Epoch 12: Train Loss = 1.4963, Val Loss = 1.3948
# Epoch 13: Train Loss = 1.4372, Val Loss = 1.3471
# Epoch 14: Train Loss = 1.3858, Val Loss = 1.2808
# Epoch 15: Train Loss = 1.3285, Val Loss = 1.2444
# Epoch 16: Train Loss = 1.2958, Val Loss = 1.1986
# Epoch 17: Train Loss = 1.2626, Val Loss = 1.1810
# Epoch 18: Train Loss = 1.2140, Val Loss = 1.1744
# Epoch 19: Train Loss = 1.1888, Val Loss = 1.1327
# Epoch 20: Train Loss = 1.1723, Val Loss = 1.1175
# Epoch 21: Train Loss = 1.1313, Val Loss = 1.0882
# Epoch 22: Train Loss = 1.1179, Val Loss = 1.0899
# Epoch 23: Train Loss = 1.0969, Val Loss = 1.0619
# Epoch 24: Train Loss = 1.0694, Val Loss = 1.0574
# Epoch 25: Train Loss = 1.0678, Val Loss = 1.0299
# Epoch 26: Train Loss = 1.0394, Val Loss = 1.0113
# Epoch 27: Train Loss = 1.0343, Val Loss = 1.0466
# Epoch 28: Train Loss = 1.0240, Val Loss = 1.0235
# Epoch 29: Train Loss = 1.0098, Val Loss = 1.0760
# Epoch 30: Train Loss = 0.9958, Val Loss = 1.0107
# Epoch 31: Train Loss = 1.0011, Val Loss = 1.0239
# Epoch 32: Train Loss = 0.9792, Val Loss = 1.0347
# Epoch 33: Train Loss = 0.9644, Val Loss = 0.9889
# Epoch 34: Train Loss = 0.9506, Val Loss = 0.9803
# Epoch 35: Train Loss = 0.9426, Val Loss = 1.0217
# Epoch 36: Train Loss = 0.9339, Val Loss = 0.9922
# Epoch 37: Train Loss = 0.9326, Val Loss = 1.1137
# Epoch 38: Train Loss = 0.9188, Val Loss = 0.9823
# Epoch 39: Train Loss = 0.9517, Val Loss = 1.0387
# Epoch 40: Train Loss = 0.9021, Val Loss = 1.0329
# Epoch 41: Train Loss = 0.9002, Val Loss = 1.0138
# Epoch 42: Train Loss = 0.8949, Val Loss = 0.9636
# Epoch 43: Train Loss = 0.8699, Val Loss = 0.9863
# Epoch 44: Train Loss = 0.8860, Val Loss = 0.9970
# Epoch 45: Train Loss = 0.8804, Val Loss = 1.0970
# Epoch 46: Train Loss = 0.8738, Val Loss = 0.9575
# Epoch 47: Train Loss = 0.8486, Val Loss = 1.0055
# Epoch 48: Train Loss = 0.8783, Val Loss = 1.2950
# Epoch 49: Train Loss = 0.9081, Val Loss = 1.0124
# Epoch 50: Train Loss = 0.8502, Val Loss = 0.9849
# Epoch 51: Train Loss = 0.8222, Val Loss = 0.9885
# Epoch 52: Train Loss = 0.8184, Val Loss = 0.9949
# Epoch 53: Train Loss = 0.8243, Val Loss = 1.0107
# Epoch 54: Train Loss = 0.8336, Val Loss = 1.0795
# Epoch 55: Train Loss = 0.8309, Val Loss = 0.9856
# Epoch 56: Train Loss = 0.7971, Val Loss = 0.9349
# Epoch 57: Train Loss = 0.7934, Val Loss = 0.9858
# Epoch 58: Train Loss = 0.8361, Val Loss = 0.9527
# Epoch 59: Train Loss = 0.8059, Val Loss = 0.9789
# Epoch 60: Train Loss = 0.7867, Val Loss = 0.9960
# Epoch 61: Train Loss = 0.7908, Val Loss = 0.9924
# Epoch 62: Train Loss = 0.7770, Val Loss = 1.0233
# Epoch 63: Train Loss = 0.7852, Val Loss = 0.9737
# Epoch 64: Train Loss = 0.7713, Val Loss = 0.9793
# Epoch 65: Train Loss = 0.7843, Val Loss = 0.9656
# Epoch 66: Train Loss = 0.7785, Val Loss = 1.0095
# Epoch 67: Train Loss = 0.7484, Val Loss = 0.9860
# Epoch 68: Train Loss = 0.7658, Val Loss = 1.0851
# Epoch 69: Train Loss = 0.7697, Val Loss = 1.1105
# Epoch 70: Train Loss = 0.7675, Val Loss = 0.9636
# Epoch 71: Train Loss = 0.7384, Val Loss = 0.9997
# Epoch 72: Train Loss = 0.7814, Val Loss = 0.9942
# Epoch 73: Train Loss = 0.7532, Val Loss = 1.0424
# Epoch 74: Train Loss = 0.7454, Val Loss = 1.1294
# Epoch 75: Train Loss = 0.7644, Val Loss = 1.0563
# Epoch 76: Train Loss = 0.7422, Val Loss = 0.9817
# Epoch 77: Train Loss = 0.7507, Val Loss = 0.9753
# Epoch 78: Train Loss = 0.7422, Val Loss = 1.0671
# Epoch 79: Train Loss = 0.7227, Val Loss = 1.0250
# Epoch 80: Train Loss = 0.7251, Val Loss = 1.0665
# Epoch 81: Train Loss = 0.7477, Val Loss = 1.0579
# Epoch 82: Train Loss = 0.7397, Val Loss = 1.0569
# Epoch 83: Train Loss = 0.7394, Val Loss = 1.0549
# Epoch 84: Train Loss = 0.7237, Val Loss = 1.0458
# Epoch 85: Train Loss = 0.7254, Val Loss = 1.0303
# Epoch 86: Train Loss = 0.7368, Val Loss = 1.1270
# Epoch 87: Train Loss = 0.7196, Val Loss = 0.9854
# Epoch 88: Train Loss = 0.7050, Val Loss = 1.0604
# Epoch 89: Train Loss = 0.7093, Val Loss = 1.1601
# Epoch 90: Train Loss = 0.7112, Val Loss = 1.0349
# Epoch 91: Train Loss = 0.7135, Val Loss = 1.0083
# Epoch 92: Train Loss = 0.7110, Val Loss = 0.9729
# Epoch 93: Train Loss = 0.7170, Val Loss = 1.0933
# Epoch 94: Train Loss = 0.7077, Val Loss = 1.1528
# Epoch 95: Train Loss = 0.7026, Val Loss = 1.0268
# Epoch 96: Train Loss = 0.7046, Val Loss = 1.0376
# Epoch 97: Train Loss = 0.7020, Val Loss = 1.0480
# Epoch 98: Train Loss = 0.7034, Val Loss = 0.9541
# Epoch 99: Train Loss = 0.6967, Val Loss = 1.1014
# Epoch 100: Train Loss = 0.7042, Val Loss = 1.0732
# Epoch 101: Train Loss = 0.7049, Val Loss = 1.0482
# Epoch 102: Train Loss = 0.6848, Val Loss = 1.0295
# Epoch 103: Train Loss = 0.6889, Val Loss = 0.9620
# Epoch 104: Train Loss = 0.6769, Val Loss = 1.0532
# Epoch 105: Train Loss = 0.6800, Val Loss = 0.9761
# Epoch 106: Train Loss = 0.6924, Val Loss = 1.0208
# Epoch 107: Train Loss = 0.6889, Val Loss = 1.1637
# Epoch 108: Train Loss = 0.6878, Val Loss = 1.0504
# Epoch 109: Train Loss = 0.6855, Val Loss = 1.0422
# Epoch 110: Train Loss = 0.6879, Val Loss = 0.9869
# Epoch 111: Train Loss = 0.6728, Val Loss = 1.0703
# Epoch 112: Train Loss = 0.6878, Val Loss = 1.1516
# Epoch 113: Train Loss = 0.6799, Val Loss = 1.0569
# Epoch 114: Train Loss = 0.6653, Val Loss = 1.0115
# Epoch 115: Train Loss = 0.6695, Val Loss = 1.0145
# Epoch 116: Train Loss = 0.6714, Val Loss = 0.9631
# Epoch 117: Train Loss = 0.6674, Val Loss = 1.2844
# Epoch 118: Train Loss = 0.6840, Val Loss = 0.9437
# Epoch 119: Train Loss = 0.6799, Val Loss = 0.9889
# Epoch 120: Train Loss = 0.6656, Val Loss = 0.9477
# Epoch 121: Train Loss = 0.6712, Val Loss = 1.0072
# Epoch 122: Train Loss = 0.6658, Val Loss = 0.9684
# Epoch 123: Train Loss = 0.6557, Val Loss = 1.0000
# Epoch 124: Train Loss = 0.6772, Val Loss = 1.0505
# Epoch 125: Train Loss = 0.6698, Val Loss = 1.0482
# Epoch 126: Train Loss = 0.6608, Val Loss = 0.9581
# Epoch 127: Train Loss = 0.6588, Val Loss = 1.0283
# Epoch 128: Train Loss = 0.6487, Val Loss = 1.0739
# Epoch 129: Train Loss = 0.6482, Val Loss = 1.0194
# Epoch 130: Train Loss = 0.6689, Val Loss = 1.0829
# Epoch 131: Train Loss = 0.6586, Val Loss = 0.9835
# Epoch 132: Train Loss = 0.6649, Val Loss = 1.0442
# Epoch 133: Train Loss = 0.6569, Val Loss = 1.0408
# Epoch 134: Train Loss = 0.6513, Val Loss = 0.9818
# Epoch 135: Train Loss = 0.6481, Val Loss = 1.0570
# Epoch 136: Train Loss = 0.6475, Val Loss = 1.1032
# Epoch 137: Train Loss = 0.6450, Val Loss = 1.0080
# Epoch 138: Train Loss = 0.6320, Val Loss = 0.9727
# Epoch 139: Train Loss = 0.6480, Val Loss = 1.0478
# Epoch 140: Train Loss = 0.6504, Val Loss = 1.1291
# Epoch 141: Train Loss = 0.6315, Val Loss = 1.0499
# Epoch 142: Train Loss = 0.6521, Val Loss = 1.0959
# Epoch 143: Train Loss = 0.6391, Val Loss = 0.9750
# Epoch 144: Train Loss = 0.6566, Val Loss = 1.0839
# Epoch 145: Train Loss = 0.6299, Val Loss = 1.1215
# Epoch 146: Train Loss = 0.6263, Val Loss = 0.9410
# Epoch 147: Train Loss = 0.6519, Val Loss = 1.1804
# Epoch 148: Train Loss = 0.6333, Val Loss = 1.0339
# Epoch 149: Train Loss = 0.6182, Val Loss = 1.0677
# Epoch 150: Train Loss = 0.6321, Val Loss = 1.1583
# Epoch 151: Train Loss = 0.6391, Val Loss = 1.0630
# Epoch 152: Train Loss = 0.6294, Val Loss = 1.0358
# Epoch 153: Train Loss = 0.6387, Val Loss = 1.0421
# Epoch 154: Train Loss = 0.6274, Val Loss = 0.9256
# Epoch 155: Train Loss = 0.6159, Val Loss = 0.9719
# Epoch 156: Train Loss = 0.6381, Val Loss = 1.1743
# Epoch 157: Train Loss = 0.6211, Val Loss = 0.9948
# Epoch 158: Train Loss = 0.6251, Val Loss = 1.1079
# Epoch 159: Train Loss = 0.6287, Val Loss = 1.0199
# Epoch 160: Train Loss = 0.6166, Val Loss = 1.0314
# Epoch 161: Train Loss = 0.6374, Val Loss = 1.0564
# Epoch 162: Train Loss = 0.6366, Val Loss = 1.2600
# Epoch 163: Train Loss = 0.6262, Val Loss = 1.0107
# Epoch 164: Train Loss = 0.6250, Val Loss = 1.0330
# Epoch 165: Train Loss = 0.6182, Val Loss = 1.0753
# Epoch 166: Train Loss = 0.6018, Val Loss = 1.0778
# Epoch 167: Train Loss = 0.6194, Val Loss = 0.9980
# Epoch 168: Train Loss = 0.6068, Val Loss = 1.0579
# Epoch 169: Train Loss = 0.5995, Val Loss = 1.0189
# Epoch 170: Train Loss = 0.6495, Val Loss = 1.1417
# Epoch 171: Train Loss = 0.6257, Val Loss = 1.0797
# Epoch 172: Train Loss = 0.6132, Val Loss = 1.0911
# Epoch 173: Train Loss = 0.6145, Val Loss = 1.1143
# Epoch 174: Train Loss = 0.6192, Val Loss = 1.0090
# Epoch 175: Train Loss = 0.6066, Val Loss = 1.0108
# Epoch 176: Train Loss = 0.6088, Val Loss = 1.1527
# Epoch 177: Train Loss = 0.6095, Val Loss = 1.0448
# Epoch 178: Train Loss = 0.6214, Val Loss = 1.1104
# Epoch 179: Train Loss = 0.5978, Val Loss = 1.0905
# Epoch 180: Train Loss = 0.6157, Val Loss = 1.0405
# Epoch 181: Train Loss = 0.6096, Val Loss = 1.1146
# Epoch 182: Train Loss = 0.6027, Val Loss = 0.9953
# Epoch 183: Train Loss = 0.5943, Val Loss = 1.0207
# Epoch 184: Train Loss = 0.6047, Val Loss = 1.1848
# Epoch 185: Train Loss = 0.6169, Val Loss = 1.0396
# Epoch 186: Train Loss = 0.6213, Val Loss = 1.1220
# Epoch 187: Train Loss = 0.5877, Val Loss = 1.0198
# Epoch 188: Train Loss = 0.5877, Val Loss = 1.0541
# Epoch 189: Train Loss = 0.5930, Val Loss = 1.0752
# Epoch 190: Train Loss = 0.6155, Val Loss = 0.9732
# Epoch 191: Train Loss = 0.6046, Val Loss = 1.0237
# Epoch 192: Train Loss = 0.5973, Val Loss = 1.0140
# Epoch 193: Train Loss = 0.5932, Val Loss = 0.9790
# Epoch 194: Train Loss = 0.5848, Val Loss = 0.9903
# Epoch 195: Train Loss = 0.6053, Val Loss = 1.0025
# Epoch 196: Train Loss = 0.5991, Val Loss = 0.9967
# Epoch 197: Train Loss = 0.5974, Val Loss = 1.0468
# Epoch 198: Train Loss = 0.6034, Val Loss = 1.1686
# Epoch 199: Train Loss = 0.5886, Val Loss = 1.0555
# Epoch 200: Train Loss = 0.5825, Val Loss = 0.9804
# Epoch 201: Train Loss = 0.6019, Val Loss = 1.1277
# Epoch 202: Train Loss = 0.5971, Val Loss = 1.0569
# Epoch 203: Train Loss = 0.5945, Val Loss = 0.9984
# Epoch 204: Train Loss = 0.5767, Val Loss = 1.1484
# Epoch 205: Train Loss = 0.6994, Val Loss = 0.9485
# Epoch 206: Train Loss = 0.5885, Val Loss = 1.1334
# Epoch 207: Train Loss = 0.6000, Val Loss = 1.2180
# Epoch 208: Train Loss = 0.5937, Val Loss = 1.1018
# Epoch 209: Train Loss = 0.5857, Val Loss = 0.9983
# Epoch 210: Train Loss = 0.5976, Val Loss = 1.0346
# Epoch 211: Train Loss = 0.5916, Val Loss = 1.1734
# Epoch 212: Train Loss = 0.5894, Val Loss = 1.1847
# Epoch 213: Train Loss = 0.5991, Val Loss = 1.0712
# Epoch 214: Train Loss = 0.5930, Val Loss = 1.1016
# Epoch 215: Train Loss = 0.5834, Val Loss = 1.0543
# Epoch 216: Train Loss = 0.5704, Val Loss = 1.0836
# Epoch 217: Train Loss = 0.5941, Val Loss = 1.0582
# Epoch 218: Train Loss = 0.5761, Val Loss = 1.0358
# Epoch 219: Train Loss = 0.5845, Val Loss = 1.1165
# Epoch 220: Train Loss = 0.5863, Val Loss = 1.0983
# Epoch 221: Train Loss = 0.5670, Val Loss = 1.0551
# Epoch 222: Train Loss = 0.5782, Val Loss = 1.0638
# Epoch 223: Train Loss = 0.5773, Val Loss = 1.0624
# Epoch 224: Train Loss = 0.5733, Val Loss = 1.0678
# Epoch 225: Train Loss = 0.5868, Val Loss = 1.0379
# Epoch 226: Train Loss = 0.5731, Val Loss = 1.1415
# Epoch 227: Train Loss = 0.5839, Val Loss = 1.0428
# Epoch 228: Train Loss = 0.5942, Val Loss = 1.0567
# Epoch 229: Train Loss = 0.5817, Val Loss = 1.1171
# Epoch 230: Train Loss = 0.5723, Val Loss = 0.9962
# Epoch 231: Train Loss = 0.5627, Val Loss = 1.0089
# Epoch 232: Train Loss = 0.5617, Val Loss = 1.0434
# Epoch 233: Train Loss = 0.5783, Val Loss = 1.0788
# Epoch 234: Train Loss = 0.5569, Val Loss = 1.1072
# Epoch 235: Train Loss = 0.5782, Val Loss = 1.0041
# Epoch 236: Train Loss = 0.5658, Val Loss = 1.0226
# Epoch 237: Train Loss = 0.5697, Val Loss = 1.1539
# Epoch 238: Train Loss = 0.5766, Val Loss = 1.1089
# Epoch 239: Train Loss = 0.5658, Val Loss = 1.0053
# Epoch 240: Train Loss = 0.5679, Val Loss = 0.9683
# Epoch 241: Train Loss = 0.5656, Val Loss = 1.0240
# Epoch 242: Train Loss = 0.5755, Val Loss = 0.9274
# Epoch 243: Train Loss = 0.5712, Val Loss = 0.9999
# Epoch 244: Train Loss = 0.5649, Val Loss = 1.0525
# Epoch 245: Train Loss = 0.5731, Val Loss = 1.0067
# Epoch 246: Train Loss = 0.5722, Val Loss = 1.0627
# Epoch 247: Train Loss = 0.5713, Val Loss = 0.9672
# Epoch 248: Train Loss = 0.5664, Val Loss = 0.9551
# Epoch 249: Train Loss = 0.5517, Val Loss = 1.0135
# Epoch 250: Train Loss = 0.5623, Val Loss = 1.0393
# Epoch 251: Train Loss = 0.5658, Val Loss = 0.9789
# Epoch 252: Train Loss = 0.5573, Val Loss = 0.9736
# Epoch 253: Train Loss = 0.5725, Val Loss = 1.1188
# Epoch 254: Train Loss = 0.5674, Val Loss = 1.0992
# Epoch 255: Train Loss = 0.5642, Val Loss = 1.1046
# Epoch 256: Train Loss = 0.5547, Val Loss = 1.0726
# Epoch 257: Train Loss = 0.5634, Val Loss = 1.0358
# Epoch 258: Train Loss = 0.5683, Val Loss = 1.0230
# Epoch 259: Train Loss = 0.5650, Val Loss = 1.0993
# Epoch 260: Train Loss = 0.5624, Val Loss = 1.0709
# Epoch 261: Train Loss = 0.5663, Val Loss = 1.0970
# Epoch 262: Train Loss = 0.5479, Val Loss = 1.0607
# Epoch 263: Train Loss = 0.5644, Val Loss = 0.9776
# Epoch 264: Train Loss = 0.5714, Val Loss = 1.1098
# Epoch 265: Train Loss = 0.5542, Val Loss = 1.0691
# Epoch 266: Train Loss = 0.5771, Val Loss = 1.0703
# Epoch 267: Train Loss = 0.5485, Val Loss = 1.1261
# Epoch 268: Train Loss = 0.5523, Val Loss = 0.9575
# Epoch 269: Train Loss = 0.5657, Val Loss = 1.0907
# Epoch 270: Train Loss = 0.5818, Val Loss = 1.1195
# Epoch 271: Train Loss = 0.5559, Val Loss = 1.0530
# Epoch 272: Train Loss = 0.5441, Val Loss = 1.1442
# Epoch 273: Train Loss = 0.5519, Val Loss = 1.0906
# Epoch 274: Train Loss = 0.5546, Val Loss = 1.1106
# Epoch 275: Train Loss = 0.5510, Val Loss = 1.1976
# Epoch 276: Train Loss = 0.5546, Val Loss = 1.1587
# Epoch 277: Train Loss = 0.5692, Val Loss = 1.1377
# Epoch 278: Train Loss = 0.5499, Val Loss = 1.0828
# Epoch 279: Train Loss = 0.5444, Val Loss = 0.9923
# Epoch 280: Train Loss = 0.5609, Val Loss = 1.0290
# Epoch 281: Train Loss = 0.5569, Val Loss = 1.0617
# Epoch 282: Train Loss = 0.5406, Val Loss = 1.0410
# Epoch 283: Train Loss = 0.5771, Val Loss = 1.1218
# Epoch 284: Train Loss = 0.5512, Val Loss = 1.0385
# Epoch 285: Train Loss = 0.5523, Val Loss = 1.1516
# Epoch 286: Train Loss = 0.5571, Val Loss = 1.0794
# Epoch 287: Train Loss = 0.5583, Val Loss = 0.9850
# Epoch 288: Train Loss = 0.5495, Val Loss = 1.1776
# Epoch 289: Train Loss = 0.5582, Val Loss = 1.0727
# Epoch 290: Train Loss = 0.5617, Val Loss = 1.1220
# Epoch 291: Train Loss = 0.5613, Val Loss = 1.1406
# Epoch 292: Train Loss = 0.5501, Val Loss = 1.0075
# Epoch 293: Train Loss = 0.5539, Val Loss = 1.0862
# Epoch 294: Train Loss = 0.5492, Val Loss = 1.1402
# Epoch 295: Train Loss = 0.5676, Val Loss = 1.0876
# Epoch 296: Train Loss = 0.5550, Val Loss = 1.0740
# Epoch 297: Train Loss = 0.5671, Val Loss = 1.0707
# Epoch 298: Train Loss = 0.5521, Val Loss = 1.1648
# Epoch 299: Train Loss = 0.5529, Val Loss = 1.0811
# Epoch 300: Train Loss = 0.5428, Val Loss = 1.1734
# Epoch 301: Train Loss = 0.5553, Val Loss = 1.2085
# Epoch 302: Train Loss = 0.7545, Val Loss = 2.7620
# Epoch 303: Train Loss = 1.6624, Val Loss = 1.0347
# Epoch 304: Train Loss = 0.5564, Val Loss = 1.0073
# Epoch 305: Train Loss = 0.5481, Val Loss = 1.0219
# Epoch 306: Train Loss = 0.5396, Val Loss = 1.0720
# Epoch 307: Train Loss = 0.5480, Val Loss = 1.0153
# Epoch 308: Train Loss = 0.5583, Val Loss = 1.0832
# Epoch 309: Train Loss = 0.5451, Val Loss = 1.1193
# Epoch 310: Train Loss = 0.5406, Val Loss = 1.1083
# Epoch 311: Train Loss = 0.5568, Val Loss = 1.1188
# Epoch 312: Train Loss = 0.5439, Val Loss = 1.0499
# Epoch 313: Train Loss = 0.5528, Val Loss = 1.0572
# Epoch 314: Train Loss = 0.5383, Val Loss = 1.0562
# Epoch 315: Train Loss = 0.5339, Val Loss = 1.1546
# Epoch 316: Train Loss = 0.5478, Val Loss = 1.1037
# Epoch 317: Train Loss = 0.5404, Val Loss = 1.0176
# Epoch 318: Train Loss = 0.5820, Val Loss = 1.1853
# Epoch 319: Train Loss = 0.5513, Val Loss = 1.0115
# Epoch 320: Train Loss = 0.5652, Val Loss = 1.2366
# Epoch 321: Train Loss = 0.5493, Val Loss = 1.2767
# Epoch 322: Train Loss = 0.5488, Val Loss = 1.1114
# Epoch 323: Train Loss = 0.5365, Val Loss = 1.1066
# Epoch 324: Train Loss = 0.5287, Val Loss = 1.1263
# Epoch 325: Train Loss = 0.5382, Val Loss = 1.0758
# Epoch 326: Train Loss = 0.5500, Val Loss = 1.1137
# Epoch 327: Train Loss = 0.5652, Val Loss = 1.1481
# Epoch 328: Train Loss = 0.5547, Val Loss = 1.0988
# Epoch 329: Train Loss = 0.5353, Val Loss = 1.0989
# Epoch 330: Train Loss = 0.5489, Val Loss = 1.0821
# Epoch 331: Train Loss = 0.5479, Val Loss = 0.9995
# Epoch 332: Train Loss = 0.5593, Val Loss = 1.0311
# Epoch 333: Train Loss = 0.5468, Val Loss = 0.9979
# Epoch 334: Train Loss = 0.5461, Val Loss = 1.0211
# Epoch 335: Train Loss = 0.5535, Val Loss = 1.1577
# Epoch 336: Train Loss = 0.5546, Val Loss = 1.1309
# Epoch 337: Train Loss = 0.5416, Val Loss = 1.0393
# Epoch 338: Train Loss = 0.5400, Val Loss = 1.0947
# Epoch 339: Train Loss = 0.5549, Val Loss = 1.1630
# Epoch 340: Train Loss = 0.5457, Val Loss = 1.0791
# Epoch 341: Train Loss = 0.5388, Val Loss = 1.1076
# Epoch 342: Train Loss = 0.5301, Val Loss = 1.2963
# Epoch 343: Train Loss = 0.5569, Val Loss = 1.1252
# Epoch 344: Train Loss = 0.5486, Val Loss = 1.1390
# Epoch 345: Train Loss = 0.5321, Val Loss = 1.0820
# Epoch 346: Train Loss = 0.5347, Val Loss = 1.0600
# Epoch 347: Train Loss = 0.5318, Val Loss = 1.0944
# Epoch 348: Train Loss = 0.5387, Val Loss = 1.1491
# Epoch 349: Train Loss = 0.5468, Val Loss = 1.2968
# Epoch 350: Train Loss = 0.5598, Val Loss = 1.2945
# Epoch 351: Train Loss = 0.5334, Val Loss = 1.2136
# Epoch 352: Train Loss = 0.5417, Val Loss = 1.1134
# Epoch 353: Train Loss = 0.5395, Val Loss = 1.2733
# Epoch 354: Train Loss = 0.5315, Val Loss = 1.0926
# Epoch 355: Train Loss = 0.5355, Val Loss = 1.1632
# Epoch 356: Train Loss = 0.5295, Val Loss = 1.0078
# Epoch 357: Train Loss = 0.5461, Val Loss = 1.0798
# Epoch 358: Train Loss = 0.5511, Val Loss = 1.0946
# Epoch 359: Train Loss = 0.5340, Val Loss = 1.0579
# Epoch 360: Train Loss = 0.5478, Val Loss = 1.2747
# Epoch 361: Train Loss = 0.5266, Val Loss = 1.1360
# Epoch 362: Train Loss = 0.5314, Val Loss = 1.1264
# Epoch 363: Train Loss = 0.5308, Val Loss = 1.1230
# Epoch 364: Train Loss = 0.5509, Val Loss = 1.0801
# Epoch 365: Train Loss = 0.5296, Val Loss = 1.1377
# Epoch 366: Train Loss = 0.5519, Val Loss = 1.1366
# Epoch 367: Train Loss = 0.5567, Val Loss = 1.1210
# Epoch 368: Train Loss = 0.5442, Val Loss = 1.0836
# Epoch 369: Train Loss = 0.5608, Val Loss = 1.0909
# Epoch 370: Train Loss = 0.5509, Val Loss = 1.1631
# Epoch 371: Train Loss = 0.5368, Val Loss = 1.1147
# Epoch 372: Train Loss = 0.5320, Val Loss = 1.0573
# Epoch 373: Train Loss = 0.5337, Val Loss = 1.3392
# Epoch 374: Train Loss = 0.5476, Val Loss = 1.1559
# Epoch 375: Train Loss = 0.5227, Val Loss = 1.1306
# Epoch 376: Train Loss = 0.5299, Val Loss = 1.0858
# Epoch 377: Train Loss = 0.5265, Val Loss = 1.1888
# Epoch 378: Train Loss = 0.5298, Val Loss = 1.0750
# Epoch 379: Train Loss = 0.5220, Val Loss = 1.2698
# Epoch 380: Train Loss = 0.5367, Val Loss = 1.1431
# Epoch 381: Train Loss = 0.5325, Val Loss = 1.1099
# Epoch 382: Train Loss = 0.5289, Val Loss = 1.1325
# Epoch 383: Train Loss = 0.5367, Val Loss = 1.0387
# Epoch 384: Train Loss = 0.5244, Val Loss = 1.2145
# Epoch 385: Train Loss = 0.5291, Val Loss = 0.9996
# Epoch 386: Train Loss = 0.5263, Val Loss = 1.0381
# Epoch 387: Train Loss = 0.5230, Val Loss = 1.0631
# Epoch 388: Train Loss = 0.5317, Val Loss = 1.2921
# Epoch 389: Train Loss = 0.5376, Val Loss = 1.0775
# Epoch 390: Train Loss = 0.5419, Val Loss = 1.3318
# Epoch 391: Train Loss = 0.5276, Val Loss = 1.1182
# Epoch 392: Train Loss = 0.5153, Val Loss = 1.0983
# Epoch 393: Train Loss = 0.5216, Val Loss = 1.2041
# Epoch 394: Train Loss = 0.5413, Val Loss = 1.1062
# Epoch 395: Train Loss = 0.5089, Val Loss = 1.0689
# Epoch 396: Train Loss = 0.5274, Val Loss = 1.0098
# Epoch 397: Train Loss = 0.5413, Val Loss = 1.2106
# Epoch 398: Train Loss = 0.5279, Val Loss = 1.0898
# Epoch 399: Train Loss = 0.5246, Val Loss = 1.1137
# Epoch 400: Train Loss = 0.5278, Val Loss = 1.1506
# Epoch 401: Train Loss = 0.5306, Val Loss = 1.0169
# Epoch 402: Train Loss = 0.5325, Val Loss = 1.0839
# Epoch 403: Train Loss = 0.5240, Val Loss = 1.0534
# Epoch 404: Train Loss = 0.5163, Val Loss = 1.0232
# Epoch 405: Train Loss = 0.5689, Val Loss = 1.1710
# Epoch 406: Train Loss = 0.5207, Val Loss = 1.0722
# Epoch 407: Train Loss = 0.5121, Val Loss = 1.1025
# Epoch 408: Train Loss = 0.5288, Val Loss = 1.0179
# Epoch 409: Train Loss = 0.5256, Val Loss = 1.0829
# Epoch 410: Train Loss = 0.5266, Val Loss = 0.9794
# Epoch 411: Train Loss = 0.5381, Val Loss = 1.1588
# Epoch 412: Train Loss = 0.5336, Val Loss = 1.0846
# Epoch 413: Train Loss = 0.5318, Val Loss = 1.1736
# Epoch 414: Train Loss = 0.5205, Val Loss = 1.0108
# Epoch 415: Train Loss = 0.5335, Val Loss = 1.1175
# Epoch 416: Train Loss = 0.5209, Val Loss = 1.1203
# Epoch 417: Train Loss = 0.5328, Val Loss = 1.0512
# Epoch 418: Train Loss = 0.5186, Val Loss = 1.0147
# Epoch 419: Train Loss = 0.5247, Val Loss = 1.0112
# Epoch 420: Train Loss = 0.5281, Val Loss = 1.0641
# Epoch 421: Train Loss = 0.5281, Val Loss = 1.2168
# Epoch 422: Train Loss = 0.5257, Val Loss = 1.0663
# Epoch 423: Train Loss = 0.5403, Val Loss = 1.1514
# Epoch 424: Train Loss = 0.5449, Val Loss = 1.1183
# Epoch 425: Train Loss = 0.5318, Val Loss = 1.1978
# Epoch 426: Train Loss = 0.5442, Val Loss = 1.2097
# Epoch 427: Train Loss = 0.5325, Val Loss = 1.0777
# Epoch 428: Train Loss = 0.5168, Val Loss = 1.0575
# Epoch 429: Train Loss = 0.5299, Val Loss = 1.1093
# Epoch 430: Train Loss = 0.5311, Val Loss = 1.0196
# Epoch 431: Train Loss = 0.5182, Val Loss = 1.0103
# Epoch 432: Train Loss = 0.5183, Val Loss = 1.0733
# Epoch 433: Train Loss = 0.5339, Val Loss = 1.1113
# Epoch 434: Train Loss = 0.5351, Val Loss = 1.0594
# Epoch 435: Train Loss = 0.5217, Val Loss = 1.0889
# Epoch 436: Train Loss = 0.5172, Val Loss = 1.1121
# Epoch 437: Train Loss = 0.5229, Val Loss = 1.2084
# Epoch 438: Train Loss = 0.5111, Val Loss = 0.9694
# Epoch 439: Train Loss = 0.5198, Val Loss = 1.1484
# Epoch 440: Train Loss = 0.5253, Val Loss = 1.0869
# Epoch 441: Train Loss = 0.5148, Val Loss = 1.0289
# Epoch 442: Train Loss = 0.5239, Val Loss = 0.9831
# Epoch 443: Train Loss = 0.5318, Val Loss = 1.1712
# Epoch 444: Train Loss = 0.5258, Val Loss = 1.0788
# Epoch 445: Train Loss = 0.5306, Val Loss = 1.0749
# Epoch 446: Train Loss = 0.5261, Val Loss = 1.1602
# Epoch 447: Train Loss = 0.5126, Val Loss = 1.0449
# Epoch 448: Train Loss = 0.5183, Val Loss = 1.1306
# Epoch 449: Train Loss = 0.5206, Val Loss = 1.0865
# Epoch 450: Train Loss = 0.5318, Val Loss = 1.0282
# Epoch 451: Train Loss = 0.5197, Val Loss = 1.0007
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-6b1c65ec756b> in <cell line: 238>()
#     270     num_epochs = 500
#     271     for epoch in range(1, num_epochs + 1):
# --> 272         train_loss = train_epoch_bert(model, train_loader, optimizer, criterion, device, mlm_probability=0.15)
#     273         val_loss = evaluate_bert(model, val_loader, criterion, device, mlm_probability=0.15)
#     274         print(f"Epoch {epoch}: Train Loss = {train_loss:.4f}, Val Loss = {val_loss:.4f}")
#
# <ipython-input-16-6b1c65ec756b> in train_epoch_bert(model, dataloader, optimizer, criterion, device, mlm_probability)
#     175         loss.backward()
#     176         optimizer.step()
# --> 177         total_loss += loss.item()
#     178     return total_loss / len(dataloader)
#     179
#
# KeyboardInterrupt:

# %%
print("working")
def test_accuracy_bert(model, dataloader, device, mlm_probability=0.15):
    """
    Computes token-level accuracy for masked language modeling on the test set.
    Only considers tokens that were masked (i.e. labels != -100).

    Returns:
        accuracy (float): the fraction of correctly predicted masked tokens.
    """
    model.eval()
    total_masked = 0
    total_correct = 0
    with torch.no_grad():
        for batch in dataloader:
            batch = batch.to(device)  # (batch, seq_len)
            # Create masked inputs and labels using the same masking function.
            masked_inputs, labels = mask_tokens(batch.clone(), SPECIAL_TOKENS["<mask>"], vocab_size, mlm_probability)
            # Transpose for Transformer: (seq_len, batch)
            masked_inputs = masked_inputs.transpose(0, 1)
            labels = labels.transpose(0, 1)
            padding_mask = generate_padding_mask(batch).to(device)
            logits = model(masked_inputs, src_padding_mask=padding_mask)
            # Get predictions (seq_len, batch)
            predictions = torch.argmax(logits, dim=-1)

            # For accuracy, we compare predictions with labels where labels != -100.
            mask = (labels != -100)
            total_masked += mask.sum().item()
            total_correct += (predictions[mask] == labels[mask]).sum().item()
    accuracy = total_correct / total_masked if total_masked > 0 else 0.0
    return accuracy

# Example usage:
accuracy = test_accuracy_bert(model, test_loader, device, mlm_probability=0.15)
print(f"Test Token-Level Accuracy on Masked Positions: {accuracy:.4f}")
# Out:
# working
# Test Token-Level Accuracy on Masked Positions: 0.8125

# %%
def sequence_accuracy_bert(model, dataloader, device, mlm_probability=0.15):
    """
    Compute sequence accuracy for masked language modeling on the test set.
    For each example, we mask tokens using the same strategy as training.
    Then, if every token in the example that was masked is predicted correctly,
    the sequence is considered correct.

    Returns:
        accuracy (float): fraction of sequences with all masked tokens predicted correctly.
    """
    model.eval()
    total_sequences = 0
    correct_sequences = 0
    with torch.no_grad():
        for batch in dataloader:
            batch = batch.to(device)  # (batch, seq_len)
            # Create masked inputs and corresponding labels.
            masked_inputs, labels = mask_tokens(batch.clone(), SPECIAL_TOKENS["<mask>"], vocab_size, mlm_probability)
            # Transpose for the Transformer: (seq_len, batch)
            masked_inputs_t = masked_inputs.transpose(0, 1)
            labels_t = labels.transpose(0, 1)
            padding_mask = generate_padding_mask(batch).to(device)
            logits = model(masked_inputs_t, src_padding_mask=padding_mask)
            predictions = torch.argmax(logits, dim=-1)  # (seq_len, batch)

            # Evaluate each sequence in the batch.
            for i in range(batch.size(0)):
                seq_labels = labels_t[:, i]
                seq_preds = predictions[:, i]
                # Only consider positions that were masked (labels != -100)
                mask_positions = (seq_labels != -100)
                # If no tokens were masked, count the sequence as correct.
                if mask_positions.sum().item() == 0:
                    correct_sequences += 1
                else:
                    if torch.equal(seq_preds[mask_positions], seq_labels[mask_positions]):
                        correct_sequences += 1
                total_sequences += 1
    return correct_sequences / total_sequences if total_sequences > 0 else 0.0

acc = sequence_accuracy_bert(model, test_loader, device, mlm_probability=0.15)
print(f"Test Sequence Accuracy: {acc:.4f}")
# Out:
# Test Sequence Accuracy: 0.0244

# %% [markdown]
# ### Task 3.4

# %%
import math
import json
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# ---------------------
# 1. Special Tokens & Vocabulary
# ---------------------
SPECIAL_TOKENS = {
    "<pad>": 0,
    "<bos>": 1,
    "<eos>": 2,
    "<mask>": 3
}

def build_vocab(dataset):
    """
    Build vocabulary from a dataset.
    Each example is a dict with keys "amplitude_tokens" and "squared_amplitude_tokens".
    Tokens from both lists are added.
    """
    vocab = dict(SPECIAL_TOKENS)
    for example in dataset:
        for token in example["amplitude_tokens"]:
            if token not in vocab:
                vocab[token] = len(vocab)
        for token in example["squared_amplitude_tokens"]:
            if token not in vocab:
                vocab[token] = len(vocab)
    return vocab

# ---------------------
# 2. Dataset and DataLoader
# ---------------------
class LanguageModelDataset(Dataset):
    def __init__(self, data, vocab, max_len=200):
        """
        data: list of dicts; each dict has keys "amplitude_tokens" and "squared_amplitude_tokens".
              Each value is a list of token strings.
        vocab: mapping from token to index.
        max_len: maximum sequence length (truncates if longer).
        """
        self.data = data
        self.vocab = vocab
        self.max_len = max_len

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        example = self.data[idx]
        # Concatenate tokens from both columns with <bos> at the start and <eos> at the end.
        tokens = ([SPECIAL_TOKENS["<bos>"]] +
                  [self.vocab[token] for token in example["amplitude_tokens"]] +
                  [self.vocab[token] for token in example["squared_amplitude_tokens"]] +
                  [SPECIAL_TOKENS["<eos>"]])
        tokens = tokens[:self.max_len]
        return torch.tensor(tokens, dtype=torch.long)

def collate_fn(batch):
    batch_size = len(batch)
    max_len = max(len(x) for x in batch)
    padded = torch.full((batch_size, max_len), SPECIAL_TOKENS["<pad>"], dtype=torch.long)
    for i, seq in enumerate(batch):
        padded[i, :len(seq)] = seq
    return padded

# ---------------------
# 3. Positional Encoding Module
# ---------------------
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        """
        Registers positional encodings with shape (max_len, 1, d_model) for inputs of shape (seq_len, batch, d_model).
        """
        super().__init__()
        self.dropout = nn.Dropout(p=dropout)
        pe = torch.zeros(max_len, d_model)  # (max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)  # (max_len, 1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(1)  # (max_len, 1, d_model)
        self.register_buffer("pe", pe)

    def forward(self, x):
        # x: (seq_len, batch, d_model)
        x = x + self.pe[:x.size(0)]
        return self.dropout(x)

# ---------------------
# 4. Custom Switch Transformer Encoder Layer with MoE
# ---------------------
class SwitchTransformerEncoderLayer(nn.Module):
    def __init__(self, d_model, nhead, d_ff, dropout, num_experts):
        """
        A Transformer encoder layer with a mixture-of-experts feedforward block.
        """
        super().__init__()
        self.self_attn = nn.MultiheadAttention(d_model, nhead, dropout=dropout)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)
        # Create a list of experts (each a feedforward network)
        self.experts = nn.ModuleList([
            nn.Sequential(
                nn.Linear(d_model, d_ff),
                nn.ReLU(),
                nn.Dropout(dropout),
                nn.Linear(d_ff, d_model)
            ) for _ in range(num_experts)
        ])
        # A gating network to compute a soft assignment over experts for each token.
        self.gate = nn.Linear(d_model, num_experts)

    def forward(self, src, src_mask=None, src_key_padding_mask=None):
        # Self-attention sub-layer.
        attn_output, _ = self.self_attn(src, src, src, attn_mask=src_mask, key_padding_mask=src_key_padding_mask)
        src = src + self.dropout(attn_output)
        src = self.norm1(src)
        # MoE feedforward sub-layer.
        # Transpose to (batch, seq_len, d_model) for gating and expert computation.
        x = src.transpose(0, 1)  # shape: (batch, seq_len, d_model)
        gate_logits = self.gate(x)  # shape: (batch, seq_len, num_experts)
        gate_probs = F.softmax(gate_logits, dim=-1)  # soft assignments

        # Compute each expert's output.
        expert_outputs = []
        for expert in self.experts:
            expert_outputs.append(expert(x))  # each output shape: (batch, seq_len, d_model)
        # Stack outputs: (batch, seq_len, num_experts, d_model)
        expert_outputs = torch.stack(expert_outputs, dim=2)
        # Weight experts by gate probabilities.
        gate_probs = gate_probs.unsqueeze(-1)  # (batch, seq_len, num_experts, 1)
        moe_output = torch.sum(gate_probs * expert_outputs, dim=2)  # (batch, seq_len, d_model)
        # Transpose back: (seq_len, batch, d_model)
        moe_output = moe_output.transpose(0, 1)
        src = src + self.dropout(moe_output)
        src = self.norm2(src)
        return src

# ---------------------
# 5. Titan-Inspired Model: TitanForMaskedLM
# ---------------------
class TitanForMaskedLM(nn.Module):
    def __init__(self, vocab_size, d_model=128, nhead=8, num_layers=6, dropout=0.1, num_persistent=16, d_ff=None, num_experts=None):
        """
        A BERT-style masked LM model inspired by Titan.
        It prepends a fixed set of learned persistent tokens to every input sequence.
        If d_ff and num_experts are provided, the model uses custom Switch Transformer layers with MoE.
        Otherwise, it defaults to standard TransformerEncoder layers.
        """
        super().__init__()
        self.d_model = d_model
        self.num_persistent = num_persistent
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.pos_encoder = PositionalEncoding(d_model, dropout)
        self.dropout = nn.Dropout(dropout)
        if d_ff is None or num_experts is None:
            # Use standard Transformer encoder layer.
            encoder_layer = nn.TransformerEncoderLayer(d_model, nhead, dim_feedforward=4*d_model, dropout=dropout)
            self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers)
        else:
            # Use custom Switch Transformer encoder layers with MoE.
            self.layers = nn.ModuleList([
                SwitchTransformerEncoderLayer(d_model, nhead, d_ff, dropout, num_experts)
                for _ in range(num_layers)
            ])
        self.fc_out = nn.Linear(d_model, vocab_size)
        # Learned persistent tokens: (num_persistent, 1, d_model)
        self.persistent_tokens = nn.Parameter(torch.randn(num_persistent, 1, d_model))

    def forward(self, src, src_padding_mask=None):
        # src: (seq_len, batch)
        batch_size = src.size(1)
        emb = self.embedding(src) * math.sqrt(self.d_model)
        emb = self.pos_encoder(emb)  # (seq_len, batch, d_model)
        persistent = self.persistent_tokens.expand(-1, batch_size, -1)
        # Concatenate persistent tokens with input embeddings.
        x = torch.cat([persistent, emb], dim=0)  # (num_persistent + seq_len, batch, d_model)
        if src_padding_mask is not None:
            # Create a zero mask for persistent tokens.
            persistent_mask = torch.zeros((batch_size, self.num_persistent), dtype=torch.bool, device=src_padding_mask.device)
            extended_mask = torch.cat([persistent_mask, src_padding_mask], dim=1)  # (batch, num_persistent + seq_len)
        else:
            extended_mask = None

        # Pass through encoder layers.
        if hasattr(self, "layers"):
            for layer in self.layers:
                x = layer(x, src_mask=None, src_key_padding_mask=extended_mask)
        else:
            x = self.transformer_encoder(x, src_key_padding_mask=extended_mask)

        # Discard outputs corresponding to persistent tokens.
        x = x[self.num_persistent:, :, :]  # (seq_len, batch, d_model)
        logits = self.fc_out(x)  # (seq_len, batch, vocab_size)
        return logits

# ---------------------
# 6. Helper Function for Padding Mask
# ---------------------
def generate_padding_mask(batch, pad_idx=SPECIAL_TOKENS["<pad>"]):
    # batch: (batch, seq_len)
    return (batch == pad_idx)

# ---------------------
# 7. Masking Function for MLM
# ---------------------
def mask_tokens(inputs, mask_token_id, vocab_size, mlm_probability=0.15):
    """
    Prepare masked token inputs/labels for MLM.
    inputs: Tensor of shape (batch, seq_len)
    Returns: masked_inputs, labels (labels are -100 for unmasked tokens)
    """
    labels = inputs.clone()
    probability_matrix = torch.full(labels.shape, mlm_probability, device=inputs.device)
    special_tokens_mask = (inputs == SPECIAL_TOKENS["<bos>"]) | \
                          (inputs == SPECIAL_TOKENS["<eos>"]) | \
                          (inputs == SPECIAL_TOKENS["<pad>"])
    probability_matrix.masked_fill_(special_tokens_mask, value=0.0)
    masked_indices = torch.bernoulli(probability_matrix).bool()
    labels[~masked_indices] = -100
    # 80% of the time, replace masked input tokens with <mask>
    indices_replaced = torch.bernoulli(torch.full(labels.shape, 0.8, device=inputs.device)).bool() & masked_indices
    inputs[indices_replaced] = mask_token_id
    # 10% of the time, replace masked input tokens with random token
    indices_random = torch.bernoulli(torch.full(labels.shape, 0.5, device=inputs.device)).bool() & masked_indices & ~indices_replaced
    random_words = torch.randint(low=0, high=vocab_size, size=inputs.shape, device=inputs.device)
    inputs[indices_random] = random_words[indices_random]
    return inputs, labels

# ---------------------
# 8. Training and Evaluation Functions for MLM
# ---------------------
def train_epoch_bert(model, dataloader, optimizer, criterion, device, mlm_probability=0.15):
    model.train()
    total_loss = 0.0
    for batch in dataloader:
        batch = batch.to(device)  # (batch, seq_len)
        masked_inputs, labels = mask_tokens(batch.clone(), SPECIAL_TOKENS["<mask>"], vocab_size, mlm_probability)
        masked_inputs = masked_inputs.transpose(0, 1)  # (seq_len, batch)
        labels = labels.transpose(0, 1)
        padding_mask = generate_padding_mask(batch).to(device)
        optimizer.zero_grad()
        logits = model(masked_inputs, src_padding_mask=padding_mask)
        loss = criterion(logits.view(-1, logits.size(-1)), labels.reshape(-1))
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(dataloader)

def evaluate_bert(model, dataloader, criterion, device, mlm_probability=0.15):
    model.eval()
    total_loss = 0.0
    with torch.no_grad():
        for batch in dataloader:
            batch = batch.to(device)
            masked_inputs, labels = mask_tokens(batch.clone(), SPECIAL_TOKENS["<mask>"], vocab_size, mlm_probability)
            masked_inputs = masked_inputs.transpose(0, 1)
            labels = labels.transpose(0, 1)
            padding_mask = generate_padding_mask(batch).to(device)
            logits = model(masked_inputs, src_padding_mask=padding_mask)
            loss = criterion(logits.view(-1, logits.size(-1)), labels.reshape(-1))
            total_loss += loss.item()
    return total_loss / len(dataloader)

def token_level_accuracy_bert(model, dataloader, device, mlm_probability=0.15):
    model.eval()
    total_masked = 0
    total_correct = 0
    with torch.no_grad():
        for batch in dataloader:
            batch = batch.to(device)
            masked_inputs, labels = mask_tokens(batch.clone(), SPECIAL_TOKENS["<mask>"], vocab_size, mlm_probability)
            masked_inputs = masked_inputs.transpose(0, 1)
            labels = labels.transpose(0, 1)
            padding_mask = generate_padding_mask(batch).to(device)
            logits = model(masked_inputs, src_padding_mask=padding_mask)
            predictions = torch.argmax(logits, dim=-1)
            mask = (labels != -100)
            total_masked += mask.sum().item()
            total_correct += (predictions[mask] == labels[mask]).sum().item()
    return total_correct / total_masked if total_masked > 0 else 0.0

def sequence_accuracy_bert(model, dataloader, device, mlm_probability=0.15):
    model.eval()
    total_sequences = 0
    correct_sequences = 0
    with torch.no_grad():
        for batch in dataloader:
            batch = batch.to(device)
            masked_inputs, labels = mask_tokens(batch.clone(), SPECIAL_TOKENS["<mask>"], vocab_size, mlm_probability)
            masked_inputs = masked_inputs.transpose(0, 1)
            labels = labels.transpose(0, 1)
            padding_mask = generate_padding_mask(batch).to(device)
            logits = model(masked_inputs, src_padding_mask=padding_mask)
            predictions = torch.argmax(logits, dim=-1)
            for i in range(labels.size(1)):
                seq_labels = labels[:, i]
                seq_preds = predictions[:, i]
                mask = (seq_labels != -100)
                if mask.sum().item() == 0:
                    correct_sequences += 1
                elif torch.equal(seq_preds[mask], seq_labels[mask]):
                    correct_sequences += 1
                total_sequences += 1
    return correct_sequences / total_sequences if total_sequences > 0 else 0.0

# ---------------------
# 9. Display Predictions for MLM
# ---------------------
def display_predictions_bert(model, dataloader, vocab, num_examples=5, device=torch.device("cpu")):
    rev_vocab = {v: k for k, v in vocab.items()}
    model.eval()
    examples_shown = 0
    with torch.no_grad():
        for batch in dataloader:
            batch = batch.to(device)
            masked_inputs, _ = mask_tokens(batch.clone(), SPECIAL_TOKENS["<mask>"], vocab_size, mlm_probability=0.15)
            for i in range(masked_inputs.size(0)):
                input_seq = masked_inputs[i].unsqueeze(0)  # (1, seq_len)
                input_seq_t = input_seq.transpose(0, 1)      # (seq_len, 1)
                padding_mask = generate_padding_mask(input_seq).to(device)
                logits = model(input_seq_t, src_padding_mask=padding_mask)
                logits = logits.transpose(0, 1)  # (1, seq_len, vocab_size)
                predictions = torch.argmax(logits, dim=-1)  # (1, seq_len)
                predictions_list = predictions.squeeze(0).tolist()  # convert to list for popping

                original = batch[i].cpu().tolist()
                display_seq = []
                # Replace <mask> tokens with the corresponding prediction.
                for orig, inp in zip(original, input_seq[0].cpu().tolist()):
                    if inp == SPECIAL_TOKENS["<mask>"]:
                        pred_token = predictions_list.pop(0) if predictions_list else None
                        display_seq.append(rev_vocab.get(pred_token, "<unk>"))
                    else:
                        display_seq.append(rev_vocab.get(orig, "<unk>"))
                print("Input (masked replaced by prediction):", " ".join(display_seq))
                print("-" * 50)
                examples_shown += 1
                if examples_shown >= num_examples:
                    return

# ---------------------
# 10. Main Training Loop and Testing
# ---------------------
if __name__ == "__main__":
    # Load data from JSON files.
    with open("processed_data/train.json") as f:
        train_data = json.load(f)
    with open("processed_data/val.json") as f:
        val_data = json.load(f)
    with open("processed_data/test.json") as f:
        test_data = json.load(f)

    combined_data = train_data + val_data + test_data
    vocab = build_vocab(combined_data)
    vocab_size = len(vocab)
    print(f"Vocabulary size: {vocab_size}")

    train_dataset = LanguageModelDataset(train_data, vocab, max_len=200)
    val_dataset = LanguageModelDataset(val_data, vocab, max_len=200)
    test_dataset = LanguageModelDataset(test_data, vocab, max_len=200)

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=collate_fn)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, collate_fn=collate_fn)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, collate_fn=collate_fn)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    # Instantiate the Titan-inspired model using the Switch (MoE) variant.
    model = TitanForMaskedLM(
        vocab_size,
        d_model=128,
        nhead=8,
        num_layers=6,
        dropout=0.1,
        num_persistent=16,
        d_ff=512,
        num_experts=4
    )
    model = model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss(ignore_index=-100)

    num_epochs = 50
    for epoch in range(1, num_epochs + 1):
        train_loss = train_epoch_bert(model, train_loader, optimizer, criterion, device, mlm_probability=0.15)
        val_loss = evaluate_bert(model, val_loader, criterion, device, mlm_probability=0.15)
        token_acc = token_level_accuracy_bert(model, val_loader, device, mlm_probability=0.15)
        seq_acc = sequence_accuracy_bert(model, val_loader, device, mlm_probability=0.15)
        print(f"Epoch {epoch}: Train Loss = {train_loss:.4f}, Val Loss = {val_loss:.4f}")
        print(f"Token-Level Accuracy: {token_acc:.4f}, Sequence Accuracy: {seq_acc:.4f}")

    print("\nSample Predictions on Test Data:")
    display_predictions_bert(model, test_loader, vocab, num_examples=50, device=device)
# Out:
# Vocabulary size: 32828
# Epoch 1: Train Loss = 3.7364, Val Loss = 3.1938
# Token-Level Accuracy: 0.2189, Sequence Accuracy: 0.0000
# Epoch 2: Train Loss = 3.1040, Val Loss = 2.8617
# Token-Level Accuracy: 0.2652, Sequence Accuracy: 0.0000
# Epoch 3: Train Loss = 2.7419, Val Loss = 2.4780
# Token-Level Accuracy: 0.3292, Sequence Accuracy: 0.0000
# Epoch 4: Train Loss = 2.3310, Val Loss = 2.1016
# Token-Level Accuracy: 0.4300, Sequence Accuracy: 0.0000
# Epoch 5: Train Loss = 2.0194, Val Loss = 1.7924
# Token-Level Accuracy: 0.5016, Sequence Accuracy: 0.0000
# Epoch 6: Train Loss = 1.7926, Val Loss = 1.6027
# Token-Level Accuracy: 0.5541, Sequence Accuracy: 0.0000
# Epoch 7: Train Loss = 1.6231, Val Loss = 1.4405
# Token-Level Accuracy: 0.5953, Sequence Accuracy: 0.0000
# Epoch 8: Train Loss = 1.4917, Val Loss = 1.2725
# Token-Level Accuracy: 0.6492, Sequence Accuracy: 0.0006
# Epoch 9: Train Loss = 1.3747, Val Loss = 1.2391
# Token-Level Accuracy: 0.6813, Sequence Accuracy: 0.0013
# Epoch 10: Train Loss = 1.2965, Val Loss = 1.1449
# Token-Level Accuracy: 0.7012, Sequence Accuracy: 0.0039
# Epoch 11: Train Loss = 1.2247, Val Loss = 1.1329
# Token-Level Accuracy: 0.7087, Sequence Accuracy: 0.0026
# Epoch 12: Train Loss = 1.1657, Val Loss = 1.0521
# Token-Level Accuracy: 0.7284, Sequence Accuracy: 0.0019
# Epoch 13: Train Loss = 1.1337, Val Loss = 1.0628
# Token-Level Accuracy: 0.7346, Sequence Accuracy: 0.0045
# Epoch 14: Train Loss = 1.0888, Val Loss = 1.0333
# Token-Level Accuracy: 0.7375, Sequence Accuracy: 0.0051
# Epoch 15: Train Loss = 1.0621, Val Loss = 0.9860
# Token-Level Accuracy: 0.7555, Sequence Accuracy: 0.0026
# Epoch 16: Train Loss = 1.0361, Val Loss = 1.0048
# Token-Level Accuracy: 0.7518, Sequence Accuracy: 0.0071
# Epoch 17: Train Loss = 0.9983, Val Loss = 0.9836
# Token-Level Accuracy: 0.7688, Sequence Accuracy: 0.0039
# Epoch 18: Train Loss = 0.9830, Val Loss = 1.0017
# Token-Level Accuracy: 0.7580, Sequence Accuracy: 0.0058
# Epoch 19: Train Loss = 0.9905, Val Loss = 0.9614
# Token-Level Accuracy: 0.7690, Sequence Accuracy: 0.0090
# Epoch 20: Train Loss = 0.9405, Val Loss = 0.9480
# Token-Level Accuracy: 0.7785, Sequence Accuracy: 0.0077
# Epoch 21: Train Loss = 0.9274, Val Loss = 0.9047
# Token-Level Accuracy: 0.7808, Sequence Accuracy: 0.0084
# Epoch 22: Train Loss = 0.9174, Val Loss = 0.9297
# Token-Level Accuracy: 0.7733, Sequence Accuracy: 0.0064
# Epoch 23: Train Loss = 0.9001, Val Loss = 0.9412
# Token-Level Accuracy: 0.7825, Sequence Accuracy: 0.0096
# Epoch 24: Train Loss = 0.8882, Val Loss = 0.9378
# Token-Level Accuracy: 0.7820, Sequence Accuracy: 0.0116
# Epoch 25: Train Loss = 0.8657, Val Loss = 0.8946
# Token-Level Accuracy: 0.7908, Sequence Accuracy: 0.0090
# Epoch 26: Train Loss = 0.8700, Val Loss = 0.9188
# Token-Level Accuracy: 0.7918, Sequence Accuracy: 0.0058
# Epoch 27: Train Loss = 0.8460, Val Loss = 1.0866
# Token-Level Accuracy: 0.7420, Sequence Accuracy: 0.0122
# Epoch 28: Train Loss = 0.8374, Val Loss = 0.9313
# Token-Level Accuracy: 0.7973, Sequence Accuracy: 0.0116
# Epoch 29: Train Loss = 0.8162, Val Loss = 0.8797
# Token-Level Accuracy: 0.7998, Sequence Accuracy: 0.0167
# Epoch 30: Train Loss = 0.7964, Val Loss = 0.8683
# Token-Level Accuracy: 0.8022, Sequence Accuracy: 0.0122
# Epoch 31: Train Loss = 0.7881, Val Loss = 0.8822
# Token-Level Accuracy: 0.7990, Sequence Accuracy: 0.0129
# Epoch 32: Train Loss = 0.7991, Val Loss = 0.9027
# Token-Level Accuracy: 0.8013, Sequence Accuracy: 0.0109
# Epoch 33: Train Loss = 0.7799, Val Loss = 0.8932
# Token-Level Accuracy: 0.8026, Sequence Accuracy: 0.0084
# Epoch 34: Train Loss = 0.7826, Val Loss = 0.9089
# Token-Level Accuracy: 0.8010, Sequence Accuracy: 0.0090
# Epoch 35: Train Loss = 0.7906, Val Loss = 0.9125
# Token-Level Accuracy: 0.8025, Sequence Accuracy: 0.0122
# Epoch 36: Train Loss = 0.7577, Val Loss = 0.8774
# Token-Level Accuracy: 0.8061, Sequence Accuracy: 0.0161
# Epoch 37: Train Loss = 0.7589, Val Loss = 0.8867
# Token-Level Accuracy: 0.8110, Sequence Accuracy: 0.0174
# Epoch 38: Train Loss = 0.7700, Val Loss = 0.9963
# Token-Level Accuracy: 0.7791, Sequence Accuracy: 0.0154
# Epoch 39: Train Loss = 0.7768, Val Loss = 0.9449
# Token-Level Accuracy: 0.7857, Sequence Accuracy: 0.0180
# Epoch 40: Train Loss = 0.7380, Val Loss = 0.9114
# Token-Level Accuracy: 0.8074, Sequence Accuracy: 0.0167
# Epoch 41: Train Loss = 0.7182, Val Loss = 0.8676
# Token-Level Accuracy: 0.8083, Sequence Accuracy: 0.0096
# Epoch 42: Train Loss = 0.7165, Val Loss = 0.9027
# Token-Level Accuracy: 0.8074, Sequence Accuracy: 0.0219
# Epoch 43: Train Loss = 0.7080, Val Loss = 0.9428
# Token-Level Accuracy: 0.8083, Sequence Accuracy: 0.0212
# Epoch 44: Train Loss = 0.7009, Val Loss = 0.9034
# Token-Level Accuracy: 0.8103, Sequence Accuracy: 0.0154
# Epoch 45: Train Loss = 0.7238, Val Loss = 0.9013
# Token-Level Accuracy: 0.7990, Sequence Accuracy: 0.0180
# Epoch 46: Train Loss = 0.7083, Val Loss = 0.9618
# Token-Level Accuracy: 0.7908, Sequence Accuracy: 0.0193
# Epoch 47: Train Loss = 0.6980, Val Loss = 0.9291
# Token-Level Accuracy: 0.8076, Sequence Accuracy: 0.0199
# Epoch 48: Train Loss = 0.7074, Val Loss = 0.9153
# Token-Level Accuracy: 0.8086, Sequence Accuracy: 0.0129
# Epoch 49: Train Loss = 0.6719, Val Loss = 0.8992
# Token-Level Accuracy: 0.8084, Sequence Accuracy: 0.0148
# Epoch 50: Train Loss = 0.6994, Val Loss = 0.9143
# Token-Level Accuracy: 0.8174, Sequence Accuracy: 0.0141
#
# Sample Predictions on Test Data:
# Input (masked replaced by prediction): <bos> 2 gamma_ 3 2 i * e ^ 2 * gamma_ { + sigma_ 12 , / 9 , eps_ 121 } * gamma_ { sigma_ 12 , gam_ 7 , del_ 5 } * 3 { j_ 6 , eta_ 9 } ( p_ 7 ) _u ^ ( * ) * * i l_ 8 , eps_ 121 * ( p_ e ) _u * e_ { i_ 910393 , del_ 5 } ^ p_ 121 ) _v 2 e_ { k_ 8 , gam_ 7 } * p_ 12 ) _v ^ ( * ) gamma_ { s_ 121 + ( - 2 ) * s_ 123 + s_ 1213 sigma_ reg_prop ) 4 / 9 * e ^ 4 * ( 16 * m_c ^ 2 * m_e ^ 2 + ( - 8 ) * m_c ^ 2 * s_ 1 12 8 * s_ 2 * s_ 3 + ( - 8 ) * m_e ^ , * eta_ 9 + 8 * s_ 5 , eps_ 6 121 * ( s_ 7 + ( - } ) * s_ 1 + s_ 8 + * ) gamma_ { - 2 ) <eos>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> * / 3 * i 2 e ^ 2 * gamma_ { + sigma_ 10 , gam_ 13 , gam_ 7 } * gamma_ / sigma_ 10 , gam_ 8 , gam_ 5 } * e_ { 3 6 , gam_ 7 } * p_ 7 ) _v * e_ { j_ 6 , gam_ 13 } ( p_ 8 ) _u ^ ( * ) * tt_ { k_ 9 , gam_ 8 i ( * 10 e _v ^ ( ^ ) * tt_ { l_ 9 , gam_ 5 } 2 p_ 13 ) _u / ( s_ * + 2 * s_ 102 + s_ 132 + reg_prop ) 4 / 9 * e ^ 4 gamma_ ( 16 * m_e ^ 2 * m_tt { 2 + 8 * m_e ^ 2 * + 1 + 8 sigma_ s_ 2 * s_ 3 + 8 10 s_ 4 , s_ 5 + 8 * m_tt ^ 2 * gam_ 6 ) * ( s_ 7 + 2 * s_ 1 + s_ 8 + reg_prop ) 13 ( - 2 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> - i * e ^ 2 * gamma_ { - tau_ 7 , gam_ i , del_ 10 } * gamma_ { tau_ 7 , * 14 e del_ 5 ^ * e_ { 2 6 , gam_ 8 * ( p_ 7 ) _v ^ ( * ) * e_ { l_ gamma_ , del_ 10 { + tau_ 7 ) _u * t_ { i_ 71673 , gam_ 14 } ( p_ 10 ) _u ^ ( * , * t_ { j_ 71653 , del_ 5 gam_ ( p_ 14 ) _v / 8 m_e , 2 + del_ 71 + 2 * s_ 72 + reg_prop ) e ^ 4 * ( 16 * m_e ^ 2 * m_t 10 2 + 8 * m_t ^ 2 * s_ 1 + 8 * s_ 2 * s_ } + 8 * s_ 4 * s_ 5 + 8 * * ^ 2 * s_ 6 ) * gamma_ { ^ 2 + s_ 7 + 2 * s_ 1 + reg_prop ) ^ tau_ 7 2 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> - i * e ^ 2 * gamma_ - + tau_ i , gam_ 10 , del_ 7 } * * { tau_ 9 , gam_ e , eps_ 5 } * e_ { i_ 6 , del_ 7 } ( p_ 7 ^ _v * e_ { k_ 8 , gam_ 2 } * p_ 9 ) _v ^ ( * ) * gamma_ { l_ 8 { + 5 } ( p_ tau_ 9 _u * , { j_ 14 , gam_ 12 } ( p_ 12 ) _u ^ ( * ) / ( s_ 91 + ( gam_ 2 ) * s_ 93 + s_ 73 + reg_prop ) e ^ 4 * ( 16 * m_e ^ 2 * 10 ^ 2 + ( - 8 ) * m_t ^ 2 * , 1 + 8 * s_ 2 * s_ 3 + del_ - 8 7 } m_e ^ 2 * s_ 4 + 8 * s_ * * gamma_ 6 ) * ( s_ 7 + ( - 2 ) * s_ 1 + { 8 + reg_prop ) ^ ( - 2 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> 2 * 2 * i * e / 2 * gamma_ 9 + mu_ 7 * eta_ i , * 10 e * gamma_ { ^ 2 , eta_ 9 , eps_ 5 } * u_ { k_ 6 , eps_ 5 } ( p_ 7 ) _u * u_ { j_ 75361 , eta_ 9 } ( p_ 9 ) _u ^ ( * ) * u_ { i_ 75361 * alpha_ 10 } ( p_ 10 ) _v gamma_ u_ { l_ 6 , eta_ 11 } ( p_ 11 ) { ^ ( * ) + ( m_u ^ 2 + - s_ 113 + 1 / 2 * reg_prop ) 4 / 81 * e ^ 4 mu_ ( 16 * m_u ^ 4 + ( - 8 7 * m_u ^ 2 * , 1 + eta_ - 7 ) * m_u ^ 2 * s_ 2 + 8 * s_ 3 * s_ 4 , 8 * s_ 5 * alpha_ 6 ) * ( m_u ^ 2 + - s_ 2 10 1 / 2 * reg_prop ) ^ ( - 2 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> - 1 / 2 * i * e ^ 2 * ( p_ 1 _ tau_ 10 * gamma_ { tau_ 16 , gam_ 12 * gam_ 5 - * gamma_ 1 tau_ 6 , gam_ 7 , gam_ 8 } * gamma_ { / tau_ 10 , gam_ 5 2 gam_ 7 } * A_ { k_ 9 , + tau_ 16 } * p_ 1 ) * A_ { l_ 9 , + tau_ 6 } ( p_ 10 ) * i { j_ 11 , gam_ 8 * e p_ 12 ) _v * t_ { i_ 11 , gam_ 12 } ^ p_ 16 ) _u ^ ( * ) 2 ( - 2 ) * p_ 16 _ tau_ 16 * * { tau_ 6 ( gam_ p_ , gam_ 15 } * A_ { k_ 9 , + tau_ 16 1 _ p_ tau_ ) * A_ { 10 9 , + tau_ 6 } ( p_ 10 ) * t_ { j_ 11 , gam_ 15 } ( p_ * ) _v * t_ { i_ 11 , gam_ 14 } gamma_ p_ 16 ) { ^ ( * ) ) tau_
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> 2 / 9 * i * e ^ 2 * gamma_ { + nu_ 8 , * 2 , beta_ 10 } * / { nu_ 8 , gam_ 11 , 9 5 } * d_ { l_ 6 , gam_ 11 } ( p_ 7 ) _v ^ ( * i * d_ { k_ * , eps_ 5 e ( p_ 8 ) _u * u_ ^ i_ 84951 , eta_ 7 } ( p_ 10 ) _u ^ 2 * ) * u_ { j_ 84951 , beta_ 10 } ( p_ 11 ) _v / ( m_d ^ 2 + * * s_ 82 + s_ 72 + reg_prop ) gamma_ { 81 * e ^ 4 * ( 16 * m_d ^ 2 * m_u ^ 2 + 8 * m_u + 2 * s_ 1 + 8 * s_ nu_ * s_ 8 , eta_ * 7 4 * s_ 5 + 8 * m_d ^ 2 * s_ 6 ) * ( m_d ^ 2 + 2 , beta_ 1 + s_ 7 + reg_prop ) 10 ( - 2 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> - 4 / 9 * i * e ^ 2 * } { mu_ 9 , - 13 , alpha_ 10 } * gamma_ 4 + mu_ 9 / gam_ 7 , del_ 5 } * u_ { j_ 6 , alpha_ 10 } ( 9 7 ) _v * u_ { k_ 8 , gam_ 7 } ( * 9 ) _v ^ ( * i * u_ { i_ 6 , eta_ 13 * ( p_ 10 ) _u ^ e ^ ) * u_ { l_ 8 , del_ 5 } ( p_ 2 ) _u / ( m_u * 2 + gamma_ 91 + 2 * s_ 92 { reg_prop mu_ 9 / 81 * e ^ 4 , eta_ 16 * m_u ^ 4 13 8 * , ^ alpha_ * s_ 1 + 10 } s_ 2 * s_ 3 + 8 * s_ 4 * s_ 5 + 8 * m_u ^ 2 * s_ 6 ) * ( m_u ^ 2 + s_ 7 + 2 gamma_ { + + reg_prop ) ^ mu_ - 2 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> - i * e ^ 2 * ( p_ 1 _ sigma_ 9 * gamma_ { sigma_ 11 , gam_ gamma_ , del_ 5 } * A_ { j_ 6 , + sigma_ 9 } ( p_ 7 ) ^ - * i * A_ { l_ 8 , * sigma_ 11 } ( p_ e ) * e_ { k_ 8 , gam_ 7 } ( p_ 1 ) _v ^ ( * ) 2 e_ { * 970301 , del_ 5 } ( p_ 11 ( _v + - p_ / 1 * p_ 7 _ nu_ 12 * gamma_ { + nu_ 12 , _ 1198125 , gam_ 1198126 } * gamma_ { sigma_ 9 , gam_ 1198096 , gam_ sigma_ } * gamma_ 9 sigma_ 11 , gam_ 1198126 , del_ 997921 } * A_ { j_ 6 , + sigma_ * } ( p_ gamma_ ) ^ ( * { * A_ { l_ 8 , + sigma_ 11 } ( p_ 9 ) * e_ { k_ 8 sigma_ gam_ 1198096 } ( p_ 1 ) _v ^ ( * ) * e_ { 11 , , del_ gamma_ } ( p_ 11
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> - 1 / 2 * * * e ^ 2 * gamma_ { + tau_ 8 , gam_ 7 , del_ - } * gamma_ 1 tau_ 8 , gam_ 10 , del_ 5 } * / { l_ 6 , 2 13 } ( p_ 7 ) _u * e_ { k_ 6 , gam_ * } ( p_ 8 ) _v ^ ( * ) * t_ { j_ 81477 , gam_ 10 } ( p_ 10 ) _u ^ ( * ) * t_ { i_ 81497 , del_ 5 } ( p_ 13 ) _v / ( m_e i 2 + * 82 + 1 e 2 * reg_prop ) 1 / 4 * e ^ 4 * ( ^ * m_e ^ 2 * m_t ^ 2 + 8 * m_t ^ 2 * s_ 1 + 2 * s_ 2 * s_ 3 + 8 * s_ 4 * s_ 5 + 8 * m_e ^ 2 gamma_ s_ 6 ) { ( m_e ^ 2 + s_ 1 + 1 / 2 tau_ reg_prop ) ^ ( - 2 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> 4 / 9 * * * e ^ 2 * ( p_ 13 _ lambda_ 2 * gamma_ { + lambda_ 2 , gam_ 131 , 4 130 } / gamma_ { mu_ 5 , 9 * , gam_ 131 } * i { tau_ 7 , * 130 , eta_ e } * A_ { j_ ^ 2 + mu_ 5 } ( p_ 130 ) ^ ( * ) * * { i_ 9 , + tau_ 7 } ( p_ 131 ) ^ ( * ) * c_ { k_ 1314001 , gam_ 6 } ( p_ 13 ) _v ^ ( * ) * c_ { l_ 1314001 , eta_ 8 p_ ( p_ 13 ) _u + - p_ 131 _ 13 _ * gamma_ lambda_ + lambda_ 2 , gam_ 14 , gam_ 15 } * gamma_ 2 mu_ 5 , gam_ 16 , gam_ 14 } * gamma_ { tau_ 7 , gam_ 15 , * 1311135 } * A_ { j_ 9 , + mu_ 5 } ( p_ 130 gamma_ { ( * ) * + { i_ lambda_ , + 2 7 } ( p_ 131 ) ^ (
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> , * e ^ 2 * ( p_ 1 _ lambda_ 22 * i { * e 22 , gam_ ^ , gam_ 10 } 2 gamma_ { tau_ 5 * ( 6 , gam_ 21 } * gamma_ { tau_ p_ , gam_ 10 , eps_ 1 } * A_ { j_ 9 , + tau_ 5 } ( p_ 10 ) ^ ( * ) * A_ { i_ 9 , + tau_ 7 } ( p_ 21 ) ^ ( * ) _ t_ { lambda_ 212683 , eps_ 8 } ( p_ 1 ) 22 * t_ { l_ 212683 , gam_ 6 } ( p_ 22 ) _v ^ ( * * + - p_ 21 _ * 22 * gamma_ { { lambda_ 22 { gam_ 14 , gam_ 15 } * gamma_ { + 5 , gam_ 16 , 22 14 } * gamma_ , tau_ 7 , gam_ 15 gam_ eps_ 213322 } * A_ { gam_ 9 , + , 5 } ( p_ 10 ) , ( 10 ) * A_ { i_ 9 , + } 7 } ( p_ 21 ) ^ ( * ) gamma_ t_
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> - 1 / 3 * i * e ^ 2 * gamma_ { + tau_ 12 , gam_ 9 , del_ 121 } * - 1 tau_ 12 , gam_ 7 , del_ 5 } * b_ { j_ 6 , del_ 5 } ( p_ 7 ) _v * b_ { l_ 8 , gam_ 7 } ( p_ 9 ) _v ^ ( * ) * e_ { i_ 939441 , del_ 121 } / p_ 121 3 _v * e_ { k_ 8 , * 9 } ( p_ 12 ) _v ^ ( * ) / ( s_ 121 + ( - 2 ) * s_ i * s_ 1213 e reg_prop ) 1 / 9 * e ^ 4 * ( 16 * ^ ^ 2 2 m_e ^ * + gamma_ - { ) * m_b ^ 2 * s_ 1 + 8 + s_ 2 * s_ 3 + ( - 8 ) * m_e ^ 2 * tau_ 4 12 8 * s_ 5 * s_ 6 ) * ( s_ 7 + ( - 2 ) * , 1 gam_ s_ 8 + reg_prop 9 ^ , - del_ )
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> i * e i 2 * ( p_ 10 * sigma_ e * ^ { lambda_ 7 , eta_ 8 , eta_ 5 } * A_ { i_ 6 , + sigma_ 2 } ( p_ 7 ) ^ ( * ) * A_ * j_ 6 , + lambda_ 7 } ( p_ 8 ( ^ p_ * ) 10 _ sigma_ k_ 74425 2 eta_ 8 } ( p_ 10 * _v ^ gamma_ * ) { lambda_ { l_ 74425 7 eta_ 5 , ( p_ 10 ) _u + - 1 / 2 * p_ 7 _ rho_ 11 * gamma_ { lambda_ 7 , eta_ 1039046 eta_ eta_ 1039082 } * gamma_ { + rho_ 11 , 8 1039082 , eta_ 1039083 } * gamma_ , sigma_ 2 , eta_ 1039083 , eta_ 1039047 } * A_ { i_ 6 5 + sigma_ 2 } * p_ 7 ) ^ ( * ) A_ A_ { j_ 6 , + { 7 } ( p_ i_ ) ^ ( 6 ) * , { + 74425 , eta_ 1039046 } ( p_ 10 ) sigma_ ^ ( * ) * mu_ { l_ 74425
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> k_ 4 / 9 - 4 * e ^ 2 * gamma_ { mu_ 12 , eta_ 9 , eta_ 120 } * gamma_ { + mu_ 12 , / 7 , eta_ 5 } * c_ { j_ 6 , 9 5 * ( p_ 7 ) _v * c_ { l_ 8 i eta_ 7 } ( p_ 9 ) _v * e * ) * u_ { i_ 6 , eta_ 9 } ( p_ 120 ) _u ^ ( * ) * u_ ^ k_ 8 2 eta_ 120 * ( p_ 12 ) _u gamma_ ( s_ 121 + ( - 2 ) * s_ 123 + s_ 1203 + reg_prop ) 16 / { * e ^ mu_ * ( 12 * m_c ^ 2 * , ^ 2 + ( - 8 ) * m_c ^ 2 * s_ 1 + eta_ * s_ 2 9 s_ 3 + ( - 8 ) * m_u ^ 2 * s_ 4 + 8 * s_ 5 , s_ 6 ) eta_ ( s_ 120 } ( - 2 ) * s_ 1 * s_ 8 + reg_prop ) ^ ( - 2 gamma_
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> 4 / 9 * i * e ^ 2 * ( p_ 1 _ sigma_ 7 * gamma_ { sigma_ 10 , gam_ * , del_ 5 } * A_ { l_ 6 , + sigma_ 7 4 / p_ 7 ) 9 A_ { j_ 8 , + sigma_ * } ( p_ 9 ) ^ i * ) * tt_ * k_ 6 , e 9 } ( p_ 1 ) _v ^ ( * ) * tt_ { i_ 8 ^ 2 5 } ( p_ 10 ) _v + 1 * 2 * p_ 7 _ tau_ 1033936 * gamma_ { sigma_ 10 , gam_ 795046 , del_ 13 } * gamma_ { sigma_ 7 , gam_ 795028 , gam_ 795045 ( p_ gamma_ { + tau_ 1033936 1 gam_ 795045 _ gam_ 795046 } sigma_ A_ { l_ 6 7 + sigma_ 7 } ( p_ 7 ) * A_ { j_ * , gamma_ sigma_ 10 } ( p_ 9 { ^ ( * ) * tt_ { sigma_ 6 , gam_ 795028 } ( p_ 1 ) _v ^ ( * ) * 10 { i_ 8 , , 13 } (
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> - i * , ^ 2 * ( p_ - _ tau_ 9 * gamma_ { tau_ i , gam_ 7 * del_ 5 } * A_ { j_ 6 , + e 9 ^ ( p_ 7 ) ^ ( * 2 * A_ { l_ 8 , + tau_ 10 } ( p_ 9 ) * t_ { i_ 6 ( del_ p_ } ( p_ 10 ) _v * t_ { k_ 8 , gam_ 7 } ( p_ 1 ) _v ^ ( * ) + - 1 / 2 * p_ 7 _ lambda_ 11 * gamma_ { + lambda_ 11 , gam_ 1071134 , 1 1071135 } * gamma_ { tau_ 9 , gam_ 1071101 , gam_ 1071134 } * gamma_ _ tau_ 10 , gam_ 1071135 , del_ 943170 } * A_ 9 j_ 6 , + * 9 } gamma_ p_ 7 ) { ( * tau_ 10 A_ { l_ 8 , + tau_ 10 } ( p_ 9 , gam_ t_ { i_ 6 , del_ 943170 7 , p_ 10 ) del_ * t_ { k_ 8 , gam_ 1071101 } ( p_ 1 ) _v ^ (
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> - 1 / * * i * - ^ 2 * gamma_ { + tau_ 10 , gam_ 11 1 eps_ 8 } * gamma_ { tau_ 10 , gam_ 7 , eta_ 5 } * e_ { j_ 6 , gam_ 11 } ( p_ 7 ) / ^ ( * ) * e_ { i_ 6 , eps_ 8 } ( p_ 8 ) _v * t_ { k_ 755 , gam_ 7 } ( p_ 10 2 _v ^ ( * ) * t_ { l_ 755 , i 5 } ( p_ 11 ) _u / ( m_t * 2 + s_ e + 1 / ^ * reg_prop ) 1 / 4 * e ^ 2 * ( 16 * gamma_ ^ 2 * m_t ^ 2 + { + m_e ^ 2 * s_ 1 + 8 * s_ 2 tau_ s_ 3 + 8 * 10 4 * s_ 5 + , * m_t ^ 2 gam_ s_ 6 ) * ( m_t ^ 2 + s_ 1 + 1 / 2 * reg_prop ) ^ ( - 2 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> - i * , ^ 2 * ( p_ 10 _ rho_ 2 * - { + rho_ 2 , gam_ i * gam_ 12 } e gamma_ { sigma_ 106396 , gam_ 6 , gam_ 13 } * gamma_ { sigma_ 106398 , gam_ ^ , eta_ 8 } * 2 { l_ 10087 , + sigma_ 106396 } ( * 10 ) * A_ { k_ 10087 ( + sigma_ 106398 } ( p_ 10 ) * e_ { j_ p_ 10 eta_ 8 } ( p_ 12 ) _ * rho_ { i_ 10089 , gam_ 6 } 2 p_ 13 ) _u ^ ( * ) + - p_ 13 * rho_ 2 * gamma_ { + rho_ 2 , gam_ 14 , gam_ 15 } * gamma_ gamma_ sigma_ { , gam_ 16 , gam_ 14 } * gamma_ { sigma_ 106398 , gam_ 15 + eta_ 100047 rho_ * A_ { 2 10087 , + , 106396 } ( p_ 10 gam_ * A_ { k_ 13 , + sigma_ 106398 } ( p_ 10 ) , e_ { j_ gam_ , eta_ 100047 12 ( } 12 ) _v * e_ {
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> - 4 / 9 * i * e ^ 2 * gamma_ { + sigma_ 11 , eta_ 110 , eps_ 8 } * gamma_ { sigma_ 11 , gam_ 7 , eps_ 5 } * u_ { j_ 6 , eps_ 8 } ( p_ , ) - 4 u_ { i_ / , eta_ 110 } ( p_ 8 ) _u ^ ( * ) * tt_ 9 l_ 9 , gam_ 7 * ( p_ 110 ) _v i ( * ) * tt_ { k_ * e eps_ 5 } ( p_ 11 ) _u / ( m_tt ^ 2 + 2 * s_ 112 + s_ 1102 + reg_prop ) 16 / 81 * e ^ 4 * ( 16 ^ m_u ^ 2 * m_tt ^ 2 2 8 * m_u gamma_ 2 * s_ 1 + 8 * s_ 2 * s_ 3 + 8 * s_ 4 * s_ 5 + 8 * m_tt ^ 2 * s_ 6 ) * ( m_tt ^ 2 + 2 * s_ { + s_ 7 + reg_prop ) ^ ( + 2 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> - 1 / 2 * i * e ^ 2 * gamma_ { + sigma_ 9 , * - , del_ 7 1 * gamma_ { / 9 , gam_ 12 , eps_ 5 } * e_ { i_ 6 , eps_ 5 } ( p_ 7 ) _v * 2 { k_ 76318 , gam_ * } ( p_ 9 ) _v ^ ( * ) * mu_ { l_ 76318 , eta_ i } ( p_ 10 ) _v ^ ( * ) * mu_ * e 76310 , ^ 7 } ( 2 12 * _v / ( m_e ^ 2 + - s_ 93 + gamma_ / 2 * reg_prop { 1 / 4 * + ^ 4 * ( 16 * m_e ^ 2 * m_mu ^ 2 sigma_ ( - 8 ) * m_mu ^ 2 * s_ 1 + 8 * s_ 2 * s_ 9 + ( - 8 ) * m_e ^ , * eta_ 4 + 8 10 s_ 5 , s_ 6 ) * ( del_ 7 2 + } s_ 1 + 1 / 2 * reg_prop ) ^ ( - 2 ) <eos> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> * i * e ^ 2 * gamma_ { + tau_ 9 , gam_ 10 , del_ 13 - * gamma_ { tau_ 9 , gam_ 7 , eps_ 5 } * t_ { j_ 6 , gam_ 7 } ( i 7 ) _u ^ ( * ) * t_ { k_ 8 , del_ 13 } * p_ 9 ) _u * t_ { l_ 8 e gam_ 10 } ( p_ 10 ) _v ^ ( * ) * t_ ^ i_ 6 2 eps_ * } ( p_ 13 ) _v / ( s_ gamma_ + 2 { s_ 92 + + 102 + reg_prop ) e ^ 4 * ( 16 * m_t ^ 4 tau_ 8 * m_t ^ 2 9 s_ 1 + 8 * s_ 2 * s_ 3 + 8 , s_ 4 * s_ 5 gam_ 10 , m_t ^ 2 * del_ 6 ) * ( 13 7 } * gamma_ s_ 1 + s_ 8 { reg_prop tau_ ^ 9 - , ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> 1 / 9 * i * e ^ 2 * , p_ 10 _ rho_ 2 1 gamma_ / rho_ 8 , eta_ 7 , eta_ 5 } * A_ { j_ 6 , + rho_ 2 } ( p_ 7 ) ^ ( * ) * A_ { i_ 6 9 + rho_ 8 } ( p_ 8 ) * i * ) * s_ { k_ 83521 , eta_ 7 * ( p_ 10 ) _v ^ e * ) * s_ { l_ 83521 ^ eta_ 5 } ( 2 10 ) _u + - 1 / 2 * p_ 7 _ lambda_ 11 * gamma_ { + lambda_ 11 , * 1011160 , eta_ 1011161 } ( gamma_ { rho_ 8 , p_ 1011121 10 eta_ 1011160 } * gamma_ { rho_ 2 , eta_ 1011161 , eta_ _ } * A_ { j_ 6 , + rho_ 2 } ( p_ 7 ) ^ , * ) * A_ { i_ 6 , + rho_ 8 } ( p_ 8 ) ^ ( * ) * s_ { k_ 83521 2 eta_ 1011121 } ( p_ 10 ) _v ^ ( * ) *
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> } / 9 4 i * e ^ 2 / ( 9 * gamma_ { nu_ 8 , gam_ 7 , gam_ 10 } * gamma_ { rho_ i , gam_ 10 * alpha_ 5 } * A_ { l_ 6 , + e 11 } ( p_ 7 ) * A_ { k_ 6 , + ^ 8 } ( p_ 8 ) * u_ { i_ 2 , alpha_ 5 * ( } 10 ) _v * m_u { j_ * , gam_ 7 } ( p_ 11 ) _u ^ ( * ) + p_ 7 gamma_ { 851256 * nu_ { nu_ 8 , gam_ 1024884 , gam_ 1024942 } * gamma_ { rho_ 11 , gam_ 1024943 8 alpha_ 800409 } * gamma_ { + tau_ , , gam_ 1024942 , gam_ gam_ } * A_ { l_ 6 , + rho_ 11 7 ( p_ 7 ) * , { k_ 6 , + nu_ gam_ } ( p_ 8 ) * u_ { i_ 77637 , alpha_ 10 } ( p_ 10 ) _v * u_ { j_ 77637 , gam_ 1024884 } ( p_ 11 ) _u ^ ( * )
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> * * i ^ 2 * gamma_ { + tau_ * , gam_ 10 , del_ 11 e * gamma_ { tau_ 7 , ^ 2 , gam_ 5 } * t_ { k_ 6 , gam_ 5 } ( p_ 7 ) _u * t_ { j_ 70717 , gam_ 9 } ( p_ 9 ) _u ^ ( * * * t_ { l_ 6 , gam_ 10 } ( p_ gamma_ ) _v ^ ( { ) + t_ { i_ 70717 , del_ 11 } ( p_ 11 ) _v / ( s_ 102 + ( - tau_ ) * s_ 103 + s_ 113 + reg_prop ) e 7 4 * ( 16 * m_t ^ 4 + , - 8 ) * m_t ^ 2 * s_ 1 + ( - 8 ) * m_t ^ 2 * s_ 2 + 8 * s_ 3 * s_ 4 + 8 * s_ 5 * s_ 6 ) * ( s_ 7 + ( - 2 gam_ * s_ 2 + s_ 8 + reg_prop ) ^ ( - 2 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> - * / 3 * i * - ^ 2 * gamma_ { + tau_ 7 , gam_ 8 , eps_ 10 } * gamma_ { tau_ 7 , gam_ 13 , del_ 5 } * b_ { k_ 6 1 del_ 5 / ( 3 7 ) _u * * { l_ 6 , i 13 } ( p_ 8 ) _v ^ ( * ) * mu_ { i_ 9 , eps_ 10 * e p_ 10 ) ^ * mu_ { j_ 9 , gam_ 2 } ( p_ 13 ) _u ^ ( * * / ( s_ 71 + 2 * s_ 72 + s_ 82 + gamma_ ) 1 / 9 * e ^ 4 * + 16 * m_b ^ 2 tau_ m_mu ^ 2 + 7 * m_mu ^ 2 , s_ gam_ + 8 * s_ 2 * s_ 3 + 8 * s_ 4 , s_ 5 + 8 * m_b ^ 2 * s_ eps_ ) * ( s_ 7 + 2 * s_ 1 + s_ 8 + 10 ) } ( - 2 * <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> 4 } 9 * i * e ^ 4 * ( p_ 1 _ tau_ 10 * gamma_ / mu_ 7 , eta_ 8 , alpha_ 5 } 9 A_ * i_ 6 , + tau_ 10 } ( p_ 7 ) ^ ( * ) * A_ { j_ 6 , + mu_ 7 } ( p_ 8 ) i ( * ) * u_ { k_ 72079 , alpha_ 5 } ( p_ 1 ) _u * * { l_ 72079 , eta_ 8 } ( e ^ ) _v ^ ( * ) + 2 1 / 2 * p_ 7 * tau_ ( * gamma_ { mu_ 7 , eta_ p_ , eta_ 16 } * gamma_ { tau_ 10 , eta_ 14 , 1 86416 _ * gamma_ { + tau_ 11 , eta_ 16 , eta_ 14 } * A_ { i_ 6 tau_ + tau_ 10 } ( p_ 10 ) * ( * ) * A_ } j_ 6 , + mu_ 7 } ( p_ 8 ) ^ ( * ) * u_ { k_ 72079 , alpha_ 86416 } ( { 1 ) _u mu_ u_ 7 l_ 72079
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> i * e ^ 2 * ( m_e * gamma_ { sigma_ 8 , gam_ 7 , gam_ 11 } * gamma_ { sigma_ 10 , gam_ * , del_ 5 } * i { l_ 6 , + sigma_ 8 } ( p_ 7 ) * A_ { k_ * , + sigma_ 10 } e p_ 8 ^ * 2 { j_ 7875 , del_ 5 } ( p_ 10 * _v * e_ { i_ 7875 , gam_ 7 } ( p_ 11 ) _u ^ ( ( ) + - p_ 7 _ tau_ 85134 m_e gamma_ { sigma_ 8 , gam_ 13 , gam_ * } * gamma_ { gamma_ 10 , gam_ { , del_ 78463 sigma_ * gamma_ { + tau_ 85134 , gam_ 14 , gam_ 15 } 8 A_ { l_ 6 , + sigma_ 8 } ( p_ 7 ) , A_ { k_ 6 , + sigma_ 10 } ( p_ 8 gam_ * e_ { j_ 7875 , del_ 78463 } 7 p_ 10 ) _v * e_ { i_ 7875 , gam_ 13 } ( p_ 11 ) _u ^ ( * ) + p_ 11
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> * / 9 * i 2 / ^ 2 * gamma_ { + 9 13 * eta_ 130 , beta_ 8 } * gamma_ { sigma_ 13 , gam_ 7 , del_ 5 } * s_ { j_ 6 , beta_ 8 i ( p_ 7 ) * * s_ { i_ 6 , eta_ 130 } ( e 8 ) _u ^ ( * ) * tt_ { l_ 9 , del_ 5 } ( p_ 130 ) ^ * tt_ 2 k_ 9 , * 7 } ( p_ 13 ) gamma_ { ( * ) / ( m_tt + 2 + s_ 131 + 2 * s_ 132 + reg_prop sigma_ 4 / 81 * e ^ 4 * ( 16 * m_s ^ 2 * m_tt ^ 2 + 8 * m_s ^ 2 * s_ 1 + 8 * s_ 2 13 s_ 3 + 8 * s_ 4 * s_ 5 + 8 * , ^ 2 * s_ 6 ) * ( m_tt ^ 2 + eta_ 7 + 2 * s_ 1 130 reg_prop ) ^ ( - 2 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> - 1 / 3 * i * e ^ 2 * gamma_ { + tau_ 11 , eta_ 110 , * 8 } * gamma_ { tau_ 11 , gam_ 7 , del_ - } * s_ { 1 6 , gam_ 8 } ( p_ 7 ) _v * s_ { i_ 6 , eta_ 110 } ( p_ 8 ) _u ^ ( * / * 3 { l_ 9 , del_ 5 } ( p_ 110 ) _u * t_ { k_ 9 , * i } ( p_ 11 ) _v ^ ( * ) / ( * ^ 2 + 2 e s_ 112 + s_ 1102 + reg_prop ) 1 / 9 * e ^ 4 ^ ( 16 2 m_s ^ 2 * m_t ^ 2 + 8 * m_s ^ 2 * s_ 1 + 8 * s_ 2 * s_ 3 * 8 * s_ 4 * s_ 5 + 8 * m_t ^ 2 * s_ 6 ) * ( m_t ^ gamma_ + 2 { s_ 1 + s_ 7 + reg_prop + tau_ ( - 2 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> 2 / 3 * i * e ^ * * gamma_ 2 + / 7 , eta_ 8 , alpha_ 10 3 * gamma_ * lambda_ 7 , eta_ 13 , del_ 5 } i c_ { k_ 6 , * 5 } ( p_ 7 ) _u * c_ { l_ 6 e eta_ * } ( p_ 8 ) _v ^ 2 * ) * mu_ { i_ 9 , eta_ 8 } ( p_ 10 ) _u ^ ( * ) * mu_ { * 9 , alpha_ 10 gamma_ ( p_ { ) _v / ( s_ 71 + + * s_ 72 + s_ 82 + lambda_ ) 4 / 9 * e ^ 4 * ( 16 * m_c ^ 2 * m_mu 7 2 + 8 * m_mu ^ , * s_ 1 + eta_ * s_ 2 * s_ 3 + 8 * s_ 4 * 8 5 + 8 , m_c alpha_ 10 * s_ 6 ) * ( s_ 7 + 2 } s_ * + s_ 8 + reg_prop ) ^ ( - 2 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> 2 / 9 * i * e * 2 * gamma_ { + sigma_ 8 , 2 7 , eps_ 10 } * / { sigma_ 8 , gam_ 13 , 9 5 } * d_ * l_ 6 , eps_ 10 } ( p_ 7 ) _u * i { k_ * e ^ 7 } ( p_ 8 ) _v ^ ( * ) * tt_ 2 i_ 76316 , gam_ 13 } ( p_ 10 ) * ^ ( * ) * tt_ { j_ 76316 , eps_ 5 } ( gamma_ 13 ) _v / ( { 81 + 2 + s_ 82 + s_ 72 + reg_prop ) 4 / sigma_ * e ^ 4 * 8 , * m_d ^ gam_ * m_tt ^ 2 + 7 * m_tt ^ 2 * s_ 1 + 8 * s_ 2 * s_ 3 + 8 * , 4 * eps_ 5 + 8 * m_d ^ 2 10 s_ } ) * ( s_ 7 + 2 * s_ 1 + s_ 8 + reg_prop ) gamma_ ( - 2 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> i * e ^ 2 ( i m_e * gamma_ { sigma_ 12 , gam_ 7 , del_ 121 } * gamma_ { sigma_ 9 , gam_ 5 , gam_ 7 } * A_ e l_ 6 , + sigma_ 9 } ( p_ 7 ) * ^ { j_ 768113 , 2 * 12 } ( p_ 9 ) ( m_e * ) * e_ { i_ 768133 , gam_ 5 * ( p_ 121 ) _u ^ ( gamma_ ) * e_ { k_ 6 , del_ 121 } { p_ 12 ) sigma_ + - p_ 7 _ 12 13 * gamma_ { + mu_ 13 , gam_ 12142290 , gam_ 12142291 } * gamma_ { gam_ 12 , gam_ 12142291 , del_ 7 , * gamma_ { sigma_ del_ , 121 12142235 , gam_ 12142290 } * A_ { * 6 , + sigma_ 9 } ( p_ 7 ) * A_ gamma_ j_ 768113 , + sigma_ { } sigma_ p_ 9 ) ^ ( * ) * 9 { i_ 768133 , gam_ 12142235 } ( p_ 121 ) _u ( 5 , ) gam_ e_ { k_ 6 , del_ 768254 }
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> 2 / 9 * i * e ^ 2 * gamma_ { rho_ 10 , eta_ 7 , , 11 2 * gamma_ / + rho_ 10 , 9 9 , eta_ 5 } * * { l_ 6 , eta_ 5 } ( p_ 7 ) _u * c_ { j_ 8 , i 9 } ( p_ 9 ) _u * ( e ) * s_ { k_ 6 , eta_ 7 } ( p_ 10 ) _v ^ ( * ) * s_ { i_ 8 , eta_ 11 ^ ( p_ 11 ) _v / 2 m_s ^ * + gamma_ - 2 ) * s_ 103 + s_ 113 + reg_prop { 4 / 81 * e ^ 4 rho_ ( 16 * m_c ^ 10 * m_s , 2 + ( - 8 ) * m_c ^ 2 * s_ 1 + 8 eta_ s_ 2 * s_ 3 + 7 - 8 ) * m_s ^ , * s_ 4 eta_ 8 * s_ 5 * 11 } ) * ( * gamma_ 2 + ( - 2 ) * { 1 + + 7 + reg_prop rho_ ^ ( 10 2
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> 2 / 9 * i * e ^ 2 ) gamma_ { + sigma_ 7 2 gam_ 10 , eta_ 9 } * gamma_ { sigma_ 7 , gam_ 12 , del_ 5 } * d_ { k_ 6 , eta_ 9 } / 9 7 ) _u * d_ { i_ 8 , gam_ * } ( i * ) _u e ( ^ ) * tt_ { l_ 6 2 del_ 5 } ( p_ * gamma_ _u * tt_ { j_ 8 , gam_ 12 { + p_ sigma_ ) _u ^ ( * 7 / ( m_d ^ , + s_ 71 + ( - 2 ) gam_ s_ 73 + reg_prop 10 4 / 81 * e ^ 4 , ( 16 * m_d eta_ 9 * } ^ 2 + ( * 8 ) * gamma_ ^ 2 * s_ 1 + 8 { sigma_ 2 * s_ 3 + ( - 8 ) * 7 ^ 2 * s_ 4 + , * s_ 5 * s_ 6 gam_ * ( m_d ^ 2 + s_ 7 + ( - 2 ) * s_ 1 + 12 ) ^ ( - 2
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> , / 9 * 1 * e ^ 2 * ( / * gamma_ { rho_ 8 , eta_ 7 , eps_ 11 } 9 gamma_ { sigma_ 10 , eta_ 5 , eta_ 7 } * A_ { l_ 6 i + rho_ 8 } ( p_ 7 ) * A_ { k_ 6 , + sigma_ * e ( p_ 8 ) * s_ { j_ 9 ^ eta_ 5 } ( p_ 10 ) _u ^ ( * ) 2 s_ { i_ 9 , eps_ 11 } ( p_ 11 * _v + p_ ( _ tau_ 704713 * gamma_ { rho_ 8 m_s eta_ * gamma_ { 854344 } * gamma_ { sigma_ 10 , eta_ 796993 , eta_ 797051 } * gamma_ { rho_ tau_ 704713 , eta_ 797051 8 eta_ 797052 } * A_ { l_ 6 , + rho_ 8 } , p_ 7 ) * A_ eta_ k_ 7 , + sigma_ 10 } , p_ 8 ) * s_ { j_ 9 eps_ eta_ 796993 } ( 11 10 ) _u ^ } * ) * s_ { * gamma_ { eps_ 854344 } ( sigma_ 11 ) _v
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> - i * e - 2 * gamma_ i + tau_ 8 , gam_ 7 , eps_ 13 } * gamma_ { tau_ 8 , e 10 , del_ 5 ^ * t_ { l_ 6 , gam_ 2 } ( * 7 ) _v ^ gamma_ * ) * t_ { k_ 6 , del_ 5 } ( p_ { ) _u * mu_ { j_ 9 , gam_ 7 } ( + 10 ) _u ^ ( * ) * mu_ { i_ tau_ , eps_ 13 } ( 8 13 ) _v / ( , 81 + 2 * s_ 82 + s_ 72 + gam_ ) e ^ 4 * ( 16 * m_t ^ 2 * m_mu ^ 7 + 8 * m_mu ^ 2 * s_ 1 + 8 * s_ * eps_ s_ 3 + 13 * s_ } * s_ 5 + 8 * m_t ^ 2 * s_ gamma_ ) * { s_ 7 + 2 * s_ 1 + s_ 8 + reg_prop ) ^ ( - 2 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> , i * e ^ 2 i ( p_ 1 _ nu_ 23 * * { + nu_ 23 , eta_ 13 , eta_ 10 } * e { sigma_ 5 , eta_ 6 , eta_ 13 } * gamma_ { sigma_ 7 , eta_ 10 , del_ ^ } * 2 { j_ 9 , * sigma_ 7 ( ( p_ 10 ) ^ ( * ) * A_ { p_ 21 , 1 sigma_ 5 } ( p_ 23 ) * mu_ { k_ 21 , eta_ 6 } ( p_ 1 ) _v ^ _ * ) * mu_ nu_ i_ 9 , del_ 8 } ( p_ 23 ) _v + p_ 23 _ nu_ 23 * gamma_ gamma_ + { 23 , eta_ 1385978 , eta_ 1385979 } * gamma_ { sigma_ + , eta_ 1385923 nu_ eta_ 1385978 } * gamma_ { sigma_ 7 , eta_ 1385979 , del_ 2305949 } * A_ { j_ 9 , + sigma_ 7 } ( p_ 10 ) ^ ( * 23 * A_ { l_ 21 , + , 5 } ( eta_ 23 ) * mu_ { k_ 21 13 eta_ 1385923 } (
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> i * e ^ } * ( m_mu * i { sigma_ 11 * eta_ 9 , alpha_ 110 } * gamma_ { tau_ 7 , eta_ e , eta_ 9 } ^ A_ { j_ 6 2 + sigma_ 11 } * p_ 7 ) ( ( m_mu ) * * gamma_ l_ 8 , + tau_ 7 } ( p_ 9 ) { mu_ { i_ 6 , eta_ sigma_ } ( p_ 110 ) _u ^ ( * ) * mu_ { k_ 8 , alpha_ 110 } ( 11 11 ) _u + - p_ 9 _ nu_ 12 * gamma_ { , nu_ eta_ , eta_ 11045287 , 9 11045288 } * , { sigma_ 11 , eta_ 11045288 alpha_ alpha_ 916707 } * gamma_ { tau_ 7 110 } 11045229 , eta_ 11045287 * * gamma_ { j_ 6 , + { 11 } ( p_ 7 tau_ ^ ( * ) * A_ { l_ 8 , + tau_ 7 } ( p_ 9 ) * mu_ { i_ 6 , 7 11045229 } ( p_ 110 ) _u ^ ( * ) * mu_ { k_ 8 , alpha_ 916707 ,
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> 4 / 9 * * * e 4 2 * ( m_u * gamma_ { mu_ 8 , gam_ 7 , gam_ 10 } * gamma_ { tau_ 11 , gam_ 10 , / 5 9 * A_ { l_ 6 , + mu_ 8 } ( p_ 7 ) * A_ { i 6 , + tau_ 11 } ( * 8 ) * e { i_ 75469 , gam_ 7 } ( p_ 10 ^ _u ^ ( * ) 2 u_ { j_ * , ( 5 } ( p_ 11 ) _v + - p_ m_u _ tau_ 838575 * gamma_ { mu_ 8 , gam_ 798674 , gam_ 798732 } gamma_ gamma_ { tau_ 11 , gam_ 798733 , del_ { } * gamma_ { + tau_ 838575 , gam_ 798732 , gam_ 798733 } * A_ { mu_ 6 , + mu_ 8 8 ( p_ 7 ) * A_ { k_ 6 , + tau_ 11 , ( p_ 8 ) * u_ { i_ 75469 , gam_ 798674 7 ( p_ 10 ) _u ^ ( * ) * u_ { j_ 75469 , del_ , } ( p_ 11 )
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> 2 / 3 * i * e ^ 2 * gamma_ * mu_ 2 , eta_ 8 , eps_ 11 } * gamma_ / 3 mu_ 7 * gam_ i , alpha_ 5 } * u_ { k_ 6 , eps_ 11 } ( p_ 7 * _u * u_ { l_ 6 , eta_ 8 } e p_ 8 ) _v ^ ( * ) * ^ { j_ 9 2 alpha_ * } ( p_ 10 gamma_ _v { mu_ { i_ 9 , gam_ 10 } ( p_ 11 ) _u ^ ( * ) mu_ ( m_u ^ 2 + 2 mu_ s_ , + s_ 82 + reg_prop ) 4 eta_ 9 * e ^ 4 * ( 16 * m_u ^ 2 * m_mu ^ 2 + 8 * m_mu ^ 2 * s_ 1 + 8 * s_ 2 * s_ 3 8 8 * s_ 4 * s_ 5 + 8 * m_u , 2 * s_ 6 ) * ( m_u ^ eps_ + 2 * s_ 1 + s_ 7 + reg_prop ) ^ ( - 2 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> ( / 3 * i * e ^ 2 * gamma_ { 2 sigma_ 8 , gam_ / , beta_ 3 } * gamma_ { sigma_ 8 , gam_ * , i 5 } * c_ { l_ 6 , gam_ 7 * ( p_ 7 ) _v ^ ( * ) * c_ { k_ 6 , e 13 } ^ p_ 8 ) _u * e_ 2 j_ 799 , * 5 } ( gamma_ { ) _v * e_ { i_ 799 , gam_ 10 } ( p_ 13 ) _u ^ ( * ) / ( m_c ^ 2 + s_ 81 + + * s_ 82 + reg_prop ) 4 / 9 * e ^ 4 * sigma_ 16 * m_c ^ 2 * m_e ^ 2 + 8 * m_e ^ 2 * s_ 1 + 8 * s_ 2 * s_ 3 + 8 8 s_ , * s_ 5 + 8 * m_c gam_ 2 * s_ 6 ) 7 ( m_c ^ 2 + s_ 7 + 2 * s_ 1 + reg_prop ) ^ ( - 2 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> 4 * 9 * i * 4 ^ 2 / gamma_ { + lambda_ 11 , gam_ 110 * beta_ * } * gamma_ { lambda_ 11 , gam_ 7 , alpha_ 5 } * c_ i j_ 6 , gam_ * } ( p_ 7 ) e ^ ( * ) * c_ { i_ 6 , gam_ 110 } ( p_ 8 ) _u ^ ( ^ ) * c_ { l_ 9 , beta_ 8 } ( p_ 110 ) _u * c_ { k_ 9 2 alpha_ * } ( p_ 11 ) _u / ( m_c ^ 2 + ( - 2 gamma_ * s_ { + * 83 lambda_ reg_prop ) 128 / 81 * e ^ 4 * ( m_c ^ 4 + - 1 / 2 * m_c ^ 11 * , 1 + - 1 / 2 * m_c ^ 2 gam_ s_ 2 + 1 / 2 110 s_ 3 * s_ 4 + 1 , 2 * s_ 5 * s_ 6 ) * ( m_c beta_ 2 + ( 7 2 } * * 2 + s_ 7 + reg_prop ) ^ ( - 2 ) <eos>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> 1 / 9 * ( * 1 ^ 2 * gamma_ { / nu_ 10 , gam_ 9 , del_ 12 } * gamma_ { 9 10 , gam_ 7 , eps_ 5 } * * { j_ i , del_ 12 } ( p_ * ) _v * d_ { l_ 8 , gam_ 9 } ( e 9 ) ^ ^ ( * ) * d_ { k_ 8 , eps_ 5 } ( 2 10 * _u * d_ { i_ 6 , gam_ 7 } ( p_ 12 ) _u ^ ( * ) / ( s_ 101 + ( gamma_ 2 ) * s_ 103 + s_ 123 { reg_prop ) 1 / 81 + e ^ 4 * ( 16 * m_d ^ 4 + ( - nu_ ) * m_d ^ 2 * s_ 1 + 8 * s_ 2 * s_ 3 + 10 - 8 ) * m_d , gam_ * s_ 9 + 8 * s_ 5 , s_ 6 ) * del_ s_ 7 + ( - 2 ) * s_ 1 + s_ 8 + reg_prop ) ^ ( - 2 ) <eos> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> - 4 / 9 , i * e ^ 2 * ( p_ 10 _ rho_ - * gamma_ { + 4 2 , gam_ 13 , gam_ / } * gamma_ { sigma_ 1057823 9 gam_ * , i 13 } * gamma_ { sigma_ * , e 12 , eta_ 8 } * ^ { k_ 2 , + sigma_ 1057825 } ( p_ 10 ) * A_ { l_ * , + sigma_ 1057823 } ( ( 10 , * tt_ , _ 11 , eta_ 8 } ( p_ 12 ) _v * tt_ { i_ 11 , gam_ 6 } ( rho_ 13 ) _u ^ ( * 2 * - p_ 13 _ rho_ 2 * gamma_ { + rho_ 2 , gam_ gamma_ , gam_ 15 } * gamma_ { sigma_ 1057823 , gam_ 16 , gam_ 14 } * { { sigma_ 1057825 + gam_ 15 , eta_ 1330436 } * A_ { k_ 9 , + sigma_ 1057825 } rho_ 2 10 ) * A_ { , gam_ 13 + sigma_ 1057823 } ( p_ 10 ) * tt_ { j_ 11 , eta_ 1330436 } ( , 12 )
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> 2 , i * e ^ 2 * ( 2 1 _ sigma_ 9 * gamma_ { sigma_ 11 i gam_ 7 , del_ 5 } * A_ { j_ 6 , + sigma_ 9 } ( p_ 7 ) ^ ( e ) * ^ { l_ 8 , + sigma_ 11 } ( p_ 9 ) * e_ { i_ 2 * del_ 5 } ( p_ 11 ) _v * ( { k_ 1 , 1 7 } ( p_ 1 ) _v _ ( sigma_ ) + 9 1 / sigma_ * p_ 7 _ mu_ 12 * gamma_ { + gamma_ 12 , { 703669 sigma_ gam_ 703670 } 11 gamma_ { sigma_ 9 , gam_ 703640 , gam_ 703669 } * gamma_ { sigma_ 11 , gam_ 703670 gam_ del_ 999817 } * gam_ { j_ 7 , + sigma_ 9 , ( p_ 7 del_ ^ ( * ) * A_ { l_ 8 , + sigma_ 11 5 ( } 9 ) * e_ { i_ 970557 , del_ A_ } ( p_ 11 ) A_ * e_ { k_ 8 { gam_ 703640 } ( p_ 1 ) j_ ^
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> - i * e ^ 2 * ( p_ 10 _ sigma_ 2 * gamma_ { + sigma_ 2 , gam_ 1012870 , gam_ 1012871 } * gamma_ { tau_ 5 , gam_ 1012811 , gam_ 1012870 } - gamma_ { tau_ 7 , gam_ 1012871 , i * e * A_ ^ k_ 9 , + tau_ 2 } ( p_ * ) * ( { l_ 9 , + tau_ 5 } ( p_ p_ ) * t_ { 10 108357 , gam_ 1012811 } ( p_ 12 ) _u _ ( * ) * t_ { j_ 108357 sigma_ del_ 8 2 ( p_ 13 ) _v + * p_ 12 _ gamma_ { * gamma_ { + sigma_ 2 , gam_ 1012872 , gam_ + } * gamma_ { tau_ 5 , gam_ sigma_ 2 , 1012872 } * gamma_ { tau_ 7 , gam_ 1012873 , del_ 17 } gam_ A_ { k_ 9 , + tau_ 7 } , p_ 10 ) * A_ { l_ , gam_ , tau_ } } ( p_ 10 ) * * { gamma_ 108357 , gam_ 1012814 } ( p_ 12 ) _u ^ ( {
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> - 1 / 2 * i * e ^ 2 * gamma_ + + tau_ 7 , gam_ 8 , eta_ - } * 1 { tau_ 7 , gam_ 13 , del_ 5 } * e_ { k_ 6 , gam_ 8 } ( / 7 ) _v 2 ( * ) * e_ * l_ 6 , eta_ 10 } ( p_ 8 ) _u * t_ { i_ 71447 , gam_ i * e p_ ^ ) _u ^ ( * 2 * t_ { gamma_ 71427 , del_ 5 } ( p_ 13 ) _v / ( m_e ^ 2 { + 72 + 1 / 2 * reg_prop tau_ 7 , gam_ * e ^ 4 * ( 16 * m_e ^ 2 * m_t ^ 2 + 8 * m_t ^ 2 * + 1 + 8 * s_ 2 * , 3 + 8 * eta_ 4 * s_ 5 + 8 * m_e ^ 2 * s_ 6 ) * ( m_e 10 2 + s_ } + 1 / 2 * * ) gamma_ ( { 2 ) <eos> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> 4 gamma_ 9 * i * 4 ^ 2 * gamma_ { lambda_ 10 , eta_ 11 , alpha_ 7 / 9 * { + i * , gam_ 8 , beta_ 5 } * c_ { i_ e , alpha_ 7 } ( p_ ^ ) 2 * c_ { j_ 6 , beta_ * } ( p_ 8 ) _v * c_ { k_ 9 , gam_ 8 } ( p_ 10 ) _v ^ ( * ) * c_ { l_ gamma_ , eta_ 11 } ( p_ 11 ) _v ^ ( { ) / ( s_ 112 + ( - 2 ) * s_ 113 + s_ 73 + reg_prop ) 128 / 81 * lambda_ ^ 10 * ( m_c ^ 4 + - 1 / 2 * m_c ^ 2 , s_ 1 + - 1 / 2 * m_c ^ 2 * s_ 2 + 1 / eta_ * s_ 3 * s_ 4 + 1 / 2 * s_ 5 * s_ 6 11 * ( s_ 7 + ( - 2 ) * s_ 2 + s_ 8 + reg_prop ) ^ ( gamma_ alpha_ 7 <eos> <pad> <pad>
# --------------------------------------------------
# Input (masked replaced by prediction): <bos> 2 / * * i * e ^ 2 * gamma_ { + tau_ 10 , gam_ 7 , gam_ 12 } * gamma_ { tau_ 10 , gam_ 9 , 2 5 } * c_ { l_ 6 , gam_ 12 } ( p_ / ) _u * c_ { j_ 8 , gam_ 7 } ( p_ 9 ) _u ^ ( * ) * t_ { k_ 6 , del_ 5 } ( p_ 10 3 _u * t_ { i_ 8 , gam_ i } ( p_ * e _u ^ ( * ) / ( m_t ^ 2 + ^ 101 + ( - 2 ) * s_ 103 + reg_prop ) 4 / 9 2 e ^ 4 * * 16 * m_c ^ 2 * m_t ^ gamma_ + ( - { ) * m_c ^ 2 * s_ 1 + 8 + s_ tau_ * 10 3 + ( - , ) * m_t ^ 2 * s_ 4 + 8 * s_ 5 gam_ s_ 6 ) * ( m_t ^ 2 + s_ 7 7 ( - 2 ) * s_ 1 + reg_prop ) , ( - 2
# --------------------------------------------------

# %%
# Compute token-level accuracy on masked positions

# Compute sequence-level accuracy (strict metric: all masked tokens must be correct)
seq_acc = sequence_accuracy_bert(model, test_loader, device, mlm_probability=0.15)
print(f"Test Sequence Accuracy: {seq_acc:.4f}")
# Out:
# Test Sequence Accuracy: 0.0174
